# %%
import os
import numpy as np
import pandas as pd

# %%
metaphe_path = "/data1/andrew/meng/mixehr/data/precomputed_results/mixmimic/mimic_trainData_mimic_trainData_JCVB0_nmar_K75_iter5497_metaphe.csv"

# %%
metaphe = pd.read_csv(metaphe_path, header=None)
metaphe
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.013136  0.012072  0.013001  0.010863  0.013223  0.012584  0.013401
# 1      0.013080  0.012152  0.013896  0.010760  0.013377  0.012294  0.024693
# 2      0.010137  0.009632  0.010108  0.008465  0.010239  0.009880  0.020405
# 3      0.009406  0.009316  0.010272  0.007866  0.009551  0.011289  0.031171
# 4      0.012823  0.011786  0.012828  0.010441  0.012946  0.012176  0.012853
# 5      0.010711  0.009901  0.010443  0.088884  0.010684  0.009841  0.013101
# 6      0.012195  0.011454  0.012193  0.009972  0.012513  0.011493  0.012399
# 7      0.003888  0.002424  0.002670  0.013008  0.002398  0.090473  0.002802
# 8      0.009769  0.028149  0.009967  0.008997  0.009743  0.008930  0.010666
# 9      0.009767  0.009106  0.009860  0.009163  0.015487  0.009205  0.009919
# 10     0.013140  0.012236  0.013341  0.010865  0.013404  0.012469  0.013572
# ...

# %%
phi_path = "/data1/andrew/meng/mixehr/data/precomputed_results/mixmimic/mimic_trainData_JCVB0_nmar_K75_iter5497_phi_normalized.csv"

# %%
phi = pd.read_csv(phi_path, header=None)
phi
# Out:
#        0     1             2             3             4             5   \
# 0       1     1  5.024310e-05  8.737840e-05  2.177550e-04  4.440120e-05
# 1       1     2  5.148710e-07  3.524580e-07  4.149710e-07  4.240080e-07
# 2       1     3  4.481980e-07  2.650990e-07  2.436900e-07  2.929340e-07
# 3       1     4  2.186530e-07  1.261510e-07  1.348660e-07  1.627780e-07
# 4       1     5  2.384470e-06  1.252600e-06  2.741040e-06  3.923540e-06
# 5       1     6  6.589700e-07  4.191120e-07  5.463610e-07  5.767480e-07
# 6       1     7  2.618370e-05  4.754320e-05  5.797970e-07  5.332730e-07
# 7       1     8  7.719620e-07  4.334450e-07  1.019010e-06  5.455620e-07
# 8       1     9  2.849190e-07  1.667370e-07  1.746950e-07  2.197520e-07
# 9       1    10  1.538120e-07  1.045250e-07  1.009700e-07  1.435430e-07
# 10      1    11  1.041980e-06  8.741510e-07  5.732810e-07  1.251950e-06
# 11      1    12  6.086670e-06  6.982830e-07  6.240440e-07  8.323480e-07
# ...

# %%
from rpy2.robjects import r, pandas2ri
import rpy2.robjects as robjects
from rpy2.robjects import default_converter
from rpy2.robjects.conversion import localconverter
pandas2ri.activate()

ehrfeat_path = "/data1/andrew/meng/mixehr/data/Mimic/version_1_3/processed/ehrFeatId.RData"
ehrfeat = r.load(ehrfeat_path)
print(len(ehrfeat))

for data in ehrfeat:
    print(data)
    print(type(robjects.globalenv))
    print(type(robjects.globalenv[data]))
    print(robjects.globalenv[data].__dict__)
    print("Names", robjects.globalenv[data].names)
    names = robjects.globalenv[data].names
    data = robjects.globalenv[data]
    as_dict = dict(zip(names, data)).items()
    for item in as_dict:
        print("ITEM", item)
        df = item[1]
        for i in df:
            print(i)
        df = pandas2ri.ri2py_dataframe(df)
        print(df)
        print()
        break
    print()

    
    
    
    
    
matrix = robjects.globalenv['obsFreqList']
matrix = pandas2ri.ri2py(matrix)
matrix

# with localconverter(default_converter + pandas2ri.converter) as cv:
# Out:
# 3
# ehrFeatInfo
# <class 'rpy2.robjects.environments.Environment'>
# <class 'rpy2.robjects.vectors.ListVector'>
# {'ro': <rpy2.robjects.vectors.VectorOperationsDelegator object at 0x7fe0eefb2898>, 'rx': <rpy2.robjects.vectors.ExtractDelegator object at 0x7fe0eefb2ba8>, 'rx2': <rpy2.robjects.vectors.DoubleExtractDelegator object at 0x7fe0eefb2278>, '__rname__': 'ehrFeatInfo'}
# Names [1] "notes"   "icd_cm"  "icd_cpt" "lab"     "presc"   "drg"
#
# ITEM ('notes', R object with classes: ('data.frame',) mapped to:
# <DataFrame - Python:0x7fe0eef37cc8 / R:0x560c7d66e5b8>
# [IntVector, FactorVector, IntVector, FactorVector]
#   typeId: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x7fe0eef37788 / R:0x560c849a75c0>
# [1, 1, 1, 1, ..., 1, 1, 1, 1]
#   term: <class 'rpy2.robjects.vectors.FactorVector'>
#   R object with classes: ('factor',) mapped to:
# <FactorVector - Python:0x7fe0eef37ac8 / R:0x560c849c7fb0>
# ...

# %%
ehrfeat.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-f815dc576cc1> in <module>
# ----> 1 ehrfeat.head()
#
# AttributeError: 'StrVector' object has no attribute 'head'

# %%
print(list(robjects.globalenv.keys()))
# Out:
# ['ehrFeatInfo', 'obsFreqList', 'stateInfo']
