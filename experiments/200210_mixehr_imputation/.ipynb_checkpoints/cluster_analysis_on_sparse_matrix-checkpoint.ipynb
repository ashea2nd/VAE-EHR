# %%
import sys
sys.path.append("./../../src")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict
import torch
from torch import nn, optim
import pickle

from vae_with_dataloader import VAE, VAETrainerWithDataLoader
# from icd_analysis_helper import ICDAnalysisHelper
from dataloader import MixehrICDImputationDataset
from visualizer_helper import Visualizer

from config_reader import Config
import os
import math
from sklearn.model_selection import train_test_split

visualizer = Visualizer()

# %%
config = Config('./config.ini', date="200211")
experiment_name=config.experiment_name
config.__dict__

local_icd_path = "/Users/andrew/Documents/meng/mimic-iii-clinical-database-1.4/D_ICD_DIAGNOSES.csv.gz"
local_patient_path = "/Users/andrew/Documents/meng/spring/PATIENT_ICD_BINARY.csv"
patient_csr_path = "/Users/andrew/Documents/meng/spring/PATIENT_ICD_BINARY_SPARSE_CSR.p"
patient_csc_path = "/Users/andrew/Documents/meng/spring/PATIENT_ICD_BINARY_SPARSE_CSC.p"

yue_admissions_path = "/Users/andrew/Documents/meng/mixEHR/data/Mimic/version_1_3/ADMISSIONS.csv.gz"
yue_df = pd.read_csv(yue_admissions_path)
yue_patient_visits = yue_df.SUBJECT_ID.value_counts()
yue_patient_idxs = yue_patient_visits[yue_patient_visits == 1]
yue_patient_idxs
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0          90          87   190659  2191-02-25 20:30:00  2191-04-25 15:18:00
# 1          91          88   123010  2111-08-29 03:03:00  2111-09-03 14:24:00
# 2          92          89   188646  2185-06-17 05:22:00  2185-06-21 11:15:00
# 3          93          91   121205  2177-04-23 00:08:00  2177-05-10 15:16:00
# 4          94          92   142807  2122-12-13 19:30:00  2123-03-04 13:47:00
# ...       ...         ...      ...                  ...                  ...
# 58971   58482       98453   111120  2138-09-04 18:54:00  2138-09-06 17:30:00
# 58972   58483       98466   183770  2189-02-26 05:05:00  2189-02-28 14:38:00
# 58973   58484       98468   193311  2174-02-14 15:37:00  2174-02-22 15:37:00
# 58974   58485       98473   106378  2154-10-25 17:12:00  2154-10-28 16:24:00
# 58975   58486       98474   104128  2191-11-18 14:43:00  2191-11-18 16:01:00
#
#                  DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION  \
# 0                      NaN        NEWBORN  PHYS REFERRAL/NORMAL DELI
# 1                      NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 2                      NaN        NEWBORN  PHYS REFERRAL/NORMAL DELI
# 3      2177-05-10 15:16:00      EMERGENCY       EMERGENCY ROOM ADMIT
# 4                      NaN        NEWBORN  PHYS REFERRAL/NORMAL DELI
# ...                    ...            ...                        ...
# 58971                  NaN      EMERGENCY  CLINIC REFERRAL/PREMATURE
# 58972                  NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 58973                  NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 58974                  NaN      EMERGENCY  CLINIC REFERRAL/PREMATURE
# 58975  2191-11-18 16:01:00      EMERGENCY  CLINIC REFERRAL/PREMATURE
#
#         DISCHARGE_LOCATION INSURANCE LANGUAGE           RELIGION  \
# 0      SHORT TERM HOSPITAL   Private      NaN       UNOBTAINABLE
# 1                     HOME   Private      NaN                NaN
# 2      SHORT TERM HOSPITAL  Medicaid      NaN       UNOBTAINABLE
# 3             DEAD/EXPIRED  Medicare      NaN             JEWISH
# 4      SHORT TERM HOSPITAL  Medicaid      NaN       UNOBTAINABLE
# ...                    ...       ...      ...                ...
# 58971                 HOME  Medicare     ENGL             JEWISH
# 58972                 HOME   Private     ENGL           CATHOLIC
# 58973     HOME HEALTH CARE   Private     ENGL           CATHOLIC
# 58974                 HOME  Medicare     ENGL  PROTESTANT QUAKER
# 58975         DEAD/EXPIRED  Self Pay     ENGL       UNOBTAINABLE
#
#       MARITAL_STATUS               ETHNICITY            EDREGTIME  \
# 0                NaN   UNKNOWN/NOT SPECIFIED                  NaN
# 1                NaN  BLACK/AFRICAN AMERICAN  2111-08-29 01:44:00
# 2                NaN   UNKNOWN/NOT SPECIFIED                  NaN
# 3            MARRIED                   WHITE  2177-04-22 21:02:00
# 4                NaN                   WHITE                  NaN
# ...              ...                     ...                  ...
# 58971        MARRIED                   WHITE  2138-09-04 11:47:00
# 58972        MARRIED                   WHITE  2189-02-26 04:27:00
# 58973        MARRIED                   WHITE  2174-02-14 11:54:00
# 58974         SINGLE  BLACK/AFRICAN AMERICAN  2154-10-25 13:08:00
# 58975            NaN   UNKNOWN/NOT SPECIFIED  2191-11-18 14:13:00
#
#                  EDOUTTIME                            DIAGNOSIS  \
# 0                      NaN                              NEWBORN
# 1      2111-08-29 02:28:00  S/P MOTOR VEHICLE ACCIDENT-STABBING
# 2                      NaN                              NEWBORN
# 3      2177-04-23 04:03:00                                FEVER
# 4                      NaN                              NEWBORN
# ...                    ...                                  ...
# 58971  2138-09-04 21:00:00                  ACUTE RENAL FAILURE
# 58972  2189-02-26 06:38:00              ACUTE CORONARY SYNDROME
# 58973  2174-02-14 16:29:00                         HIP FRACTURE
# 58974  2154-10-25 19:44:00                       LOWER GI BLEED
# 58975  2191-11-18 15:01:00                             S/P FALL
#
#        HOSPITAL_EXPIRE_FLAG  HAS_IOEVENTS_DATA  HAS_CHARTEVENTS_DATA
# 0                         0                  1                     1
# 1                         0                  1                     1
# 2                         0                  1                     1
# 3                         1                  1                     1
# 4                         0                  1                     1
# ...                     ...                ...                   ...
# 58971                     0                  1                     1
# 58972                     0                  1                     1
# 58973                     0                  1                     1
# 58974                     0                  1                     1
# 58975                     1                  0                     1
#
# [58976 rows x 20 columns]

# %%
icd9codes = pd.read_csv(local_icd_path)
icd_columns = pd.read_csv("PATIENT_ICD_ICD9_CODES.csv")

patient_csr = pickle.load(open(patient_csr_path, "rb"))
yue_patient_csr = patient_csr[yue_patient_idxs]
patient_csc = pickle.load(open(patient_csc_path, "rb"))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-79-d818969757cd> in <module>
#       3
#       4 patient_csr = pickle.load(open(patient_csr_path, "rb"))
# ----> 5 yue_patient_csr = patient_csr[yue_patient_idxs]
#       6 patient_csc = pickle.load(open(patient_csc_path, "rb"))
#
# /opt/anaconda3/envs/mengp369/lib/python3.6/site-packages/scipy/sparse/_index.py in __getitem__(self, key)
#      33     """
#      34     def __getitem__(self, key):
# ---> 35         row, col = self._validate_indices(key)
#      36         # Dispatch to specialized methods.
#      37         if isinstance(row, INT_TYPES):
#
# /opt/anaconda3/envs/mengp369/lib/python3.6/site-packages/scipy/sparse/_index.py in _validate_indices(self, key)
#     137                 row += M
#     138         elif not isinstance(row, slice):
# --> 139             row = self._asindices(row, M)
#     140
#     141         if isintlike(col):
#
# /opt/anaconda3/envs/mengp369/lib/python3.6/site-packages/scipy/sparse/_index.py in _asindices(self, idx, length)
#     169         max_indx = x.max()
#     170         if max_indx >= length:
# --> 171             raise IndexError('index (%d) out of range' % max_indx)
#     172
#     173         min_indx = x.min()
#
# IndexError: index (99999) out of range

# %%
icd_cols_list = np.squeeze(icd_columns.as_matrix(), axis=1).tolist()
icd_freqs = np.array(patient_csc.sum(axis=0))[0].tolist()

icd_label_freqs = zip(icd_cols_list, icd_freqs)

top_icd_pairs = sorted(icd_label_freqs, key=lambda pair: pair[1], reverse=True)

k = 10 
top_k_pairs = top_icd_pairs[:k]
print(top_k_pairs)

top_k_icds = [p[0] for p in top_k_pairs]
top_k_freqs = [p[1] for p in top_k_pairs]
# Out:
# [('4019', 17613), ('41401', 10775), ('42731', 10271), ('4280', 9843), ('5849', 7687), ('2724', 7465), ('25000', 7370), ('51881', 6719), ('5990', 5779), ('V053', 5776)]
# /opt/anaconda3/envs/mengp369/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.

# %%
top_k_icd_info = icd9codes[icd9codes.ICD9_CODE.isin(top_k_icds)]
top_k_icd_info
# Out:
#        ROW_ID ICD9_CODE               SHORT_TITLE  \
# 1588     1591     25000  DMII wo cmp nt st uncntr
# 2390     2747      2724    Hyperlipidemia NEC/NOS
# 4303     4304      4019          Hypertension NOS
# 4373     4374     41401  Crnry athrscl natve vssl
# 4461     4462     42731       Atrial fibrillation
# 4472     4473      4280                   CHF NOS
# 5550     5279     51881  Acute respiratry failure
# 5906     5908      5849  Acute kidney failure NOS
# 6550     6376      5990  Urin tract infection NOS
# 13229   12202      V053  Need prphyl vc vrl hepat
#
#                                               LONG_TITLE
# 1588   Diabetes mellitus without mention of complicat...
# 2390                Other and unspecified hyperlipidemia
# 4303                  Unspecified essential hypertension
# 4373   Coronary atherosclerosis of native coronary ar...
# 4461                                 Atrial fibrillation
# 4472               Congestive heart failure, unspecified
# 5550                           Acute respiratory failure
# 5906                   Acute kidney failure, unspecified
# 6550         Urinary tract infection, site not specified
# 13229  Need for prophylactic vaccination and inoculat...

# %%
tidx = icd_columns[icd_columns.ICD9_CODE == '25000'].index[0]
print(patient_csc[:, tidx].nonzero()[0].tolist())
# Out:
# [6, 11, 18, 23, 38, 45, 78, 83, 84, 87, 91, 97, 99, 114, 130, 146, 148, 150, 153, 160, 166, 177, 181, 192, 200, 216, 239, 241, 242, 255, 266, 269, 278, 287, 301, 325, 327, 329, 342, 366, 367, 368, 371, 375, 380, 382, 388, 401, 427, 439, 442, 461, 462, 468, 470, 473, 476, 487, 494, 495, 507, 516, 541, 542, 546, 549, 550, 557, 568, 575, 584, 596, 601, 602, 603, 607, 631, 650, 658, 665, 669, 677, 702, 704, 713, 722, 742, 749, 764, 769, 773, 777, 782, 789, 794, 795, 799, 815, 835, 841, 844, 858, 866, 873, 874, 885, 906, 910, 913, 917, 933, 943, 947, 949, 953, 960, 979, 992, 995, 1004, 1007, 1010, 1011, 1014, 1015, 1021, 1027, 1041, 1059, 1068, 1072, 1073, 1075, 1081, 1099, 1100, 1105, 1109, 1120, 1124, 1125, 1128, 1130, 1131, 1135, 1158, 1168, 1177, 1189, 1190, 1193, 1205, 1208, 1215, 1223, 1225, 1231, 1244, 1250, 1264, 1267, 1269, 1299, 1301, 1310, 1314, 1317, 1319, 1331, 1338, 1341, 1353, 1369, 1384, 1394, 1398, 1403, 1409, 1410, 1421, 1425, 1429, 1465, 1466, 1469, 1475, 1477, 1478, 1479, 1484, 1495, 1502, 1515, 1521, 1529, 1535, 1537, 1548, 1549, 1574, 1581, 1585, 1587, 1589, 1604, 1616, 1623, 1649, 1660, 1667, 1668, 1677, 1686, 1706, 1712, 1725, 1730, 1741, 1743, 1754, 1771, 1778, 1803, 1805, 1809, 1810, 1814, 1816, 1822, 1830, 1843, 1847, 1850, 1859, 1863, 1867, 1870, 1877, 1893, 1906, 1912, 1936, 1942, 1943, 1951, 1979, 1986, 1992, 2004, 2005, 2008, 2012, 2033, 2041, 2051, 2052, 2058, 2059, 2063, 2066, 2090, 2094, 2096, 2111, 2114, 2119, 2123, 2130, 2137, 2143, 2151, 2156, 2157, 2159, 2160, 2168, 2169, 2185, 2189, 2191, 2207, 2209, 2221, 2223, 2232, 2238, 2243, 2259, 2269, 2271, 2275, 2281, 2296, 2310, 2314, 2316, 2323, 2334, 2353, 2364, 2370, 2372, 2395, 2398, 2403, 2404, 2436, 2449, 2454, 2462, 2464, 2470, 2476, 2499, 2501, 2508, 2520, 2522, 2529, 2536, 2551, 2554, 2558, 2585, 2600, 2602, 2620, 2622, 2623, 2642, 2648, 2650, 2657, 2661, 2664, 2666, 2677, 2684, 2700, 2702, 2722, 2726, 2729, 2734, 2748, 2751, 2776, 2778, 2780, 2782, 2783, 2823, 2853, 2863, 2878, 2903, 2908, 2922, 2939, 2942, 2963, 2967, 2991, 2993, 3001, 3002, 3004, 3012, 3014, 3015, 3019, 3027, 3035, 3038, 3040, 3041, 3044, 3045, 3049, 3051, 3054, 3059, 3066, 3070, 3077, 3084, 3093, 3094, 3095, 3101, 3112, 3122, 3129, 3152, 3155, 3160, 3162, 3168, 3185, 3189, 3196, 3199, 3200, 3204, 3205, 3208, 3211, 3213, 3214, 3215, 3225, 3231, 3241, 3244, 3262, 3267, 3268, 3270, 3274, 3280, 3287, 3295, 3304, 3306, 3308, 3310, 3311, 3321, 3348, 3353, 3354, 3356, 3357, 3365, 3379, 3382, 3393, 3395, 3400, 3413, 3416, 3419, 3420, 3421, 3422, 3434, 3437, 3444, 3448, 3449, 3461, 3478, 3489, 3490, 3491, 3493, 3503, 3514, 3518, 3519, 3525, 3527, 3538, 3541, 3558, 3562, 3571, 3582, 3586, 3587, 3589, 3602, 3606, 3614, 3615, 3618, 3625, 3628, 3631, 3632, 3640, 3643, 3650, 3655, 3658, 3674, 3676, 3692, 3694, 3709, 3710, 3714, 3720, 3721, 3746, 3749, 3756, 3774, 3785, 3790, 3798, 3802, 3809, 3823, 3827, 3830, 3833, 3858, 3860, 3864, 3876, 3881, 3882, 3890, 3900, 3903, 3908, 3913, 3919, 3921, 3930, 3931, 3942, 3960, 3972, 3974, 3975, 3978, 3984, 3999, 4000, 4002, 4005, 4009, 4017, 4018, 4026, 4045, 4062, 4074, 4087, 4089, 4091, 4094, 4105, 4116, 4119, 4121, 4122, 4134, 4141, 4145, 4152, 4171, 4179, 4183, 4184, 4188, 4189, 4208, 4233, 4235, 4237, 4242, 4249, 4252, 4271, 4288, 4291, 4295, 4301, 4315, 4319, 4320, 4323, 4336, 4340, 4355, 4365, 4368, 4391, 4401, 4406, 4408, 4419, 4429, 4431, 4432, 4437, 4444, 4448, 4508, 4511, 4522, 4524, 4529, 4531, 4538, 4548, 4551, 4552, 4563, 4569, 4570, 4582, 4583, 4593, 4604, 4622, 4625, 4627, 4640, 4641, 4642, 4646, 4656, 4679, 4706, 4712, 4719, 4724, 4731, 4738, 4739, 4744, 4745, 4748, 4762, 4766, 4778, 4798, 4804, 4805, 4814, 4827, 4837, 4848, 4855, 4856, 4870, 4879, 4882, 4883, 4891, 4894, 4898, 4904, 4922, 4923, 4929, 4933, 4934, 4942, 4944, 4949, 4951, 4971, 4973, 4987, 4988, 4989, 4990, 4992, 4993, 4999, 5023, 5050, 5051, 5053, 5068, 5069, 5078, 5086, 5089, 5092, 5096, 5102, 5108, 5109, 5113, 5118, 5129, 5137, 5139, 5150, 5153, 5167, 5168, 5170 ...

# %%
patients_with_top_k = []
for icd in top_k_icds:
    icd_idx = icd_columns[icd_columns.ICD9_CODE == icd].index[0]
    patients_with_icd = patient_csc[:, icd_idx].nonzero()[0]
    
    patients_with_top_k.append((icd, patients_with_icd))
# Out:
# array([    4,     6,    11, ..., 46515, 46516, 46517], dtype=int32)

# %%
###Encode and plot 3d Data
epoch=10
X_umap_3d = pickle.load(open("X_umap_3d.p", 'rb'))
mean_umap_3d = pickle.load(open("mean_umap_3d.p", 'rb'))
var_umap_3d = pickle.load(open("var_umap_3d.p", 'rb'))

icd_test = patients_with_top_k[0][0]
patient_subset = patients_with_top_k[0][1]

alpha3d = 0.2
colors = np.array([1 for i in range(X_umap_3d.shape[0])])
colors[patient_subset] = 0
cohort = "everyone_vs_top_1_icd"


visualizer.plot2d(
    X=X_umap_3d[:, :-1], 
    filename="Patient_Clusters_2D_exp_{}_epoch_{}_{}".format(experiment_name, epoch, cohort, "_from_3d"), 
    colors=colors,
    alpha = alpha3d
)

visualizer.plot2d(
    X=mean_umap_3d[:, :-1], 
    filename="Patient_Clusters_2D_exp_{}_epoch_{}{}".format(experiment_name, epoch, cohort, "__means_from_3d"), 
    colors=colors,
    alpha = alpha3d
)

visualizer.plot2d(
    X=var_umap_3d[:, :-1], 
    filename="Patient_Clusters_2D_exp_{}_epoch_{}{}".format(experiment_name, epoch, cohort, "_vars_from_3d"), 
    colors=colors,
    alpha = alpha3d
)

visualizer.plot3d(
    X=X_umap_3d, 
    filename="Patient_Clusters_3D_exp_{}_epoch_{}{}".format(experiment_name, epoch, cohort, ""), 
    colors=colors,
    alpha = alpha3d
)

visualizer.plot3d(
    X=mean_umap_3d, 
    filename="Patient_Clusters_3D_exp_{}_epoch_{}{}".format(experiment_name, epoch, cohort, "_means"), 
    colors=colors,
    alpha = alpha3d
)

visualizer.plot3d(
    X=var_umap_3d, 
    filename="Patient_Clusters_3D_exp_{}_epoch_{}{}".format(experiment_name, epoch, cohort, "_vars"), 
    colors=colors,
    alpha = alpha3d
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-ad287d9029b4> in <module>
#      10 alpha3d = 0.2
#      11 colors = np.array([1 for i in range(X_umap_3d.shape[0])])
# ---> 12 colors[patient_subset] = 0
#      13 cohort = "everyone_vs_top_1_icd"
#      14
#
# IndexError: index 38072 is out of bounds for axis 0 with size 38071
