# %%
import sys
sys.path.append("./../../src")
from visualizer_helper import Visualizer
from cluster_helper import ClusterProcessor

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn import preprocessing
from scipy.sparse import csr_matrix
from scipy.stats import entropy
import scipy
import pickle
import os
from annoy import AnnoyIndex
from scipy.sparse.linalg import inv

from collections import Counter
from sklearn.feature_extraction import DictVectorizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/andrew/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
k_neighbors = 50
knn_clusters = 50
keep_k_evecs = 10
drop_k_evecs=2

cluster_assignments = pd.read_csv("./data/CLUSTER_ASSIGNMENTS.csv")
icd9codes = pd.read_csv("../../data/PATIENT_ICD_ICD9_CODES.csv")
patient_icd_binary = pickle.load(open("../../data/PATIENT_ICD_BINARY_SPARSE_CSR.p", 'rb'))
icd9diag = pd.read_csv("../../../mimic/D_ICD_DIAGNOSES.csv.gz")
icd9proc = pd.read_csv("../../../mimic/D_ICD_PROCEDURES.csv.gz")

icd_to_phecode = pd.read_csv("./phecode_icd9_map_unrolled.csv")
phecode_definitions = pd.read_csv("./phecode_definitions.csv")

A = pickle.load(open("./data/A_mknn_K{}_CSR.p".format(k_neighbors), "rb"))

Y_cluster_labels = pickle.load(open("./data/cluster_labels_K{}_knn{}_topkevecs{}_drop{}.p".format(k_neighbors, knn_clusters, keep_k_evecs, drop_k_evecs), 'rb'))
Y_mc_cluster_labels = pickle.load(open("./data/cluster_labels_mc_K{}_knn{}_topkevecs{}_drop{}.p".format(k_neighbors, knn_clusters, keep_k_evecs, drop_k_evecs), 'rb'))

# %%
cluster_assignments["CLUSTER"].max()
# Out:
# 49

# %%
icd9codes
# Out:
#      ICD9_CODE
# 0         0030
# 1         0031
# 2         0038
# 3         0039
# 4         0041
# ...        ...
# 6979      V902
# 6980     V9039
# 6981     V9081
# 6982     V9089
# 6983     V9103
#
# [6984 rows x 1 columns]

# %%
icd9codes_asarray = icd9codes["ICD9_CODE"].tolist()
len(icd9codes_asarray)
# Out:
# 6984

# %%
icd9diag
# Out:
#        ROW_ID ICD9_CODE               SHORT_TITLE  \
# 0         174     01166     TB pneumonia-oth test
# 1         175     01170    TB pneumothorax-unspec
# 2         176     01171   TB pneumothorax-no exam
# 3         177     01172  TB pneumothorx-exam unkn
# 4         178     01173  TB pneumothorax-micro dx
# ...       ...       ...                       ...
# 14562   14432     V7399     Scrn unspcf viral dis
# 14563   14433      V740     Screening for cholera
# 14564   14434      V741    Screening-pulmonary TB
# 14565   14435      V742     Screening for leprosy
# 14566   14436      V743  Screening for diphtheria
#
#                                               LONG_TITLE
# 0      Tuberculous pneumonia [any form], tubercle bac...
# 1                  Tuberculous pneumothorax, unspecified
# 2      Tuberculous pneumothorax, bacteriological or h...
# 3      Tuberculous pneumothorax, bacteriological or h...
# 4      Tuberculous pneumothorax, tubercle bacilli fou...
# ...                                                  ...
# 14562  Special screening examination for unspecified ...
# 14563                  Screening examination for cholera
# 14564   Screening examination for pulmonary tuberculosis
# 14565  Screening examination for leprosy (Hansen's di...
# 14566               Screening examination for diphtheria
#
# [14567 rows x 4 columns]

# %%
def cluster_size_quartiles(cluster_labels): 
    cluster_label_counts = Counter(cluster_labels).items()
    cluster_labels = [p[0] for p in cluster_label_counts]
    cluster_sizes = [p[1] for p in cluster_label_counts]
    return (np.quantile(cluster_sizes, 0.25), np.quantile(cluster_sizes, 0.75))

y_cluster_quartiles = cluster_size_quartiles(Y_cluster_labels)
y_mc_cluster_quartiles = cluster_size_quartiles(Y_mc_cluster_labels)

print(y_cluster_quartiles, y_mc_cluster_quartiles)
# Out:
# (423.75, 1151.75) (345.5, 1143.5)

# %%
#Current scatter plot plots top 3 diseases _ cluster index _ cluster size
#Clusters of interest in order from most to least promising: 
#small = (43, 21, 34)
#medium = (10, 38)
#large = (9, 35)
#NOTE: We want to do a comparison internally across cluster sizes and externally. 
#This means you want to show that small clusters capture diferent things from eachother, repeat with med and lg
#THEN do a comparison across the sizes
#Select the top 10 ICD9 Codes for brevity

def top_cluster_feats(cluster_i, n_top_feats=10):
    #Get features in cluster
    pidx_in_cluster_i = cluster_assignments[cluster_assignments["CLUSTER"] == cluster_i]['ORIGINAL_INDEX']
    pfeats_in_cluster_i = patient_icd_binary[pidx_in_cluster_i]

    #Sum them up to find most common ICD codes
    pfeats_distr_in_cluster_i = np.asarray(pfeats_in_cluster_i.sum(axis=0))

    icd9codes_aslist = icd9codes["ICD9_CODE"].tolist()

    icd_freq_pairs_in_cluster_i = list(zip(icd9codes_aslist, pfeats_distr_in_cluster_i[0]))
    icd_freq_pairs_in_cluster_i = sorted(icd_freq_pairs_in_cluster_i, key=lambda p: p[1], reverse=True)
    #print(icd_freq_pairs_in_cluster_i)
    #Use only the top n ICD9 codes
    top_icds_freqs_in_cluster_i = icd_freq_pairs_in_cluster_i[:n_top_feats]
    top_icds_in_cluster_i = [p[0] for p in top_icds_freqs_in_cluster_i]
    top_freqs_in_cluster_i = [p[1] for p in top_icds_freqs_in_cluster_i]

    #NOTE total_feats_in_cluster_i is NOT equal to the number of members in a cluster
    sum_top_feats_in_cluster_i = np.sum(top_freqs_in_cluster_i)

    top_icd_percent_occurence_in_cluster_i = [float(f)/sum_top_feats_in_cluster_i for f in top_freqs_in_cluster_i]

    top_icd9_titles = []
    for icd in top_icds_in_cluster_i:
        try:
            long_title = icd9diag[icd9diag['ICD9_CODE'] == icd]["LONG_TITLE"].values[0]
            top_icd9_titles.append(long_title)
        except:
            print("No data found for ICD code {}".format(icd))
            pass

    icd_title_strs_in_cluster_i = ["icd:{}_{}".format(top_icds_in_cluster_i[p], top_icd9_titles[p]) for p in range(n_top_feats)]
    top_feats_in_cluster_i_dict = {"CLUSTER": [cluster_i] * n_top_feats, 
                                   "ICD9_CODE": top_icds_in_cluster_i, 
                                   "ICD9_FREQS": top_freqs_in_cluster_i,
                                   "ICD9_PERCENTAGE": top_icd_percent_occurence_in_cluster_i, 
                                   "LONG_TITLE": top_icd9_titles, 
                                   "ICD_TITLE": icd_title_strs_in_cluster_i}

    top_feats_in_cluster_i_df = pd.DataFrame(top_feats_in_cluster_i_dict)
    return top_feats_in_cluster_i_df

def feats_for_clusters(specific_clusters_of_interest):
    cluster_dfs = []
    for ci in specific_clusters_of_interest:
        ci_df = top_cluster_feats(ci, 5)
        cluster_dfs.append(ci_df)

    cluster_dfs = pd.concat(cluster_dfs)
    unique_icd9codes = pd.unique(cluster_dfs["ICD9_CODE"])
    icd_idx_mapping = {k: v for v, k in enumerate(unique_icd9codes)}
    
    icd_to_icd_title_mapping = {}
    for icd in unique_icd9codes:
        icd_title = cluster_dfs[cluster_dfs["ICD9_CODE"] == icd]["ICD_TITLE"].values[0]
        icd_to_icd_title_mapping[icd] = icd_title
        
    percentage_dfs = []
#     ci = specific_clusters_of_interest[0]
    for ci in specific_clusters_of_interest:
        percentage_vec = np.zeros(len(icd_idx_mapping))

        c_df = cluster_dfs[cluster_dfs["CLUSTER"] == ci]
        c_icds = c_df["ICD9_CODE"].tolist()
        c_percentages = c_df["ICD9_PERCENTAGE"].tolist()

        #Populate the percentage vector with values
        for i, icd in enumerate(c_icds):
            icd_idx = icd_idx_mapping[icd]
            percentage_vec[icd_idx] = c_percentages[i]

        #Use percentage vector to build a dataframe row    
        icd_percentage_pairs = []
        for icd, icd_idx in icd_idx_mapping.items():
            icd_title = icd_to_icd_title_mapping[icd]
            percentage = percentage_vec[icd_idx]
            icd_percentage_pairs.append((icd_title, percentage))
            
        cluster_feat_row = dict(icd_percentage_pairs)
        cluster_feat_row["CLUSTER"] = "C{}".format(ci)
        cluster_percentages_df = pd.DataFrame([cluster_feat_row])
        percentage_dfs.append(cluster_percentages_df)
        
    return pd.concat(percentage_dfs)
   
#Visualize top ICDs => make sure ~5-10 are highly enriched
def heatmap_clusters(cluster_percentage_df, title):
    heatmap_data = cluster_percentage_df.drop("CLUSTER", axis=1).transpose()
    plt.figure(figsize=(5,10))
    g = sns.heatmap(heatmap_data, cmap="Reds", linewidths=2)
    g.set_yticklabels(g.get_yticklabels(), rotation = 0, fontsize = 12)
    g.set_xticklabels(cluster_percentage_df['CLUSTER'])
    g.set_title(title, fontsize=15)
    plt.savefig("./heatmaps/heatmap_{}.png".format(title), bbox_inches='tight')

# %%
small_clusters = [43, 11, 35, 21, 13, 42]
small_clusters_percentages_df = feats_for_clusters(small_clusters)
heatmap_clusters(small_clusters_percentages_df, title="Small Clusters\n(<423 Patients)")

# %%
medium_clusters = [10, 29, 6, 48, 0, 47]
medium_clusters_percentages_df = feats_for_clusters(medium_clusters)
heatmap_clusters(medium_clusters_percentages_df, title="Medium Clusters\n(>423, <1151 Patients)")

# %%
large_clusters = [26, 44, 14, 17, 16, 15]
large_clusters_percentages_df = feats_for_clusters(large_clusters)
heatmap_clusters(large_clusters_percentages_df, title="Large Clusters\n(>1151 Patients)")

# %%
#1.Need to show that clusters make sense -> pheCode or mortality analysis
# Current idea is to verify using co-occurence matching across clusters. 
#This is where u look for the number of patients across clusters who share 2 diseases. 
#If your clustering is good, you expect that this number differs across clusters, showing that each cluster captures
#something interesting / you can find a mix between the two.
#This is also beneficial bc it allows you to look at genetic coocurrence as well
#To do this, you need to map relevant ICD codes to pheCodes bc icd codes r too specific. Doctors also use phecodes more
#Then, you need to just to basic counting of patients with 2 classes of diseases and hope that these vary across ur clusters.

# %%
def load_phecode_file(file):
    col_names = pd.read_csv(file, nrows=0).columns
    types_dict = {'icd9': str, 'phecode': str}
    types_dict.update({col: str for col in col_names})
    return pd.read_csv(file, dtype=types_dict)

icd_to_phecode = load_phecode_file("phecode_icd9_map_unrolled.csv")
phecode_defs = load_phecode_file("phecode_definitions.csv")
icd_to_phecode
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-18e574773efd> in <module>
#       5     return pd.read_csv(file, dtype=types_dict)
#       6
# ----> 7 icd_to_phecode = load_phecode_file("phecode_icd9_map_unrolled.csv")
#       8 phecode_defs = load_phecode_file("phecode_definitions.csv")
#       9 icd_to_phecode
#
# <ipython-input-1-18e574773efd> in load_phecode_file(file)
#       1 def load_phecode_file(file):
# ----> 2     col_names = pd.read_csv(file, nrows=0).columns
#       3     types_dict = {'icd9': str, 'phecode': str}
#       4     types_dict.update({col: str for col in col_names})
#       5     return pd.read_csv(file, dtype=types_dict)
#
# NameError: name 'pd' is not defined

# %%
def remove_decimals_from_phecodes(phecode):
    pos = phecode.find(".")
    if pos == -1:
        return phecode
    else:
        shortened_phecode = phecode[:pos]
        #if this shortened phecode does not exist
        if len(phecode_defs[phecode_defs['phecode'] == shortened_phecode]) == 0:
            return phecode
        return shortened_phecode
    
#Remove periods from icd9codes
icd_to_phecode['icd9'] = icd_to_phecode["icd9"].apply(func=lambda x: x.replace(".", ""))

icd_to_phecode_no_decimals = icd_to_phecode.copy()
icd_to_phecode_no_decimals['phecode'] = icd_to_phecode_no_decimals['phecode'].apply(func=remove_decimals_from_phecodes)
icd_to_phecode_no_decimals['phecode'].unique().shape
# Out:
# (545,)

# %%
#Only keep phecodes with corresponding / existing ICD codes
def add_phenotype_names(phecode):
    phenotype = phecode_defs[phecode_defs["phecode"] == phecode]['phenotype'].values[0]
    return phenotype

icd_phecode_name_mapping = icd_to_phecode_no_decimals[icd_to_phecode_no_decimals['icd9'].isin(icd9codes['ICD9_CODE'])]
icd_phecode_name_mapping['phenotype'] = icd_phecode_name_mapping['phecode'].apply(func=add_phenotype_names)

#icd_phecode_name_mapping.to_csv("./data/icd9_phecode_mapping.csv", index=False)

# %%
icd_phecode_name_mapping = pd.read_csv('./data/icd9_phecode_mapping.csv', dtype={"phecode":str})

icd_phecode_name_mapping['phecode'].unique().shape
# Out:
# (535,)

# %%
def get_phecode_and_phenotype_from_icd9(icd9):
    
    phecode = icd_phecode_name_mapping[icd_phecode_name_mapping['icd9'] == icd9]['phecode'].values[0]
    phenotype = icd_phecode_name_mapping[icd_phecode_name_mapping['icd9'] == icd9]['phenotype'].values[0]
    return (phecode, phenotype)
#     return {"phecode":phecode, "phenotype":phenotype}

def phecode_distribution_for_cluster_i(cluster_i): 
    pidx_in_cluster_i = cluster_assignments[cluster_assignments["CLUSTER"] == cluster_i]['ORIGINAL_INDEX']
    pfeats_in_cluster_i = patient_icd_binary[pidx_in_cluster_i]
    pfeats_distr_in_cluster_i = np.asarray(pfeats_in_cluster_i.sum(axis=0))

    icd9codes_aslist = icd9codes["ICD9_CODE"].tolist()

    icd_freq_pairs_in_cluster_i = list(zip(icd9codes_aslist, pfeats_distr_in_cluster_i[0]))
    icd_freq_pairs_in_cluster_i = sorted(icd_freq_pairs_in_cluster_i, key=lambda p: p[1], reverse=True)
    icd_freq_pairs_in_cluster_i_nonzeros = [p for p in icd_freq_pairs_in_cluster_i if p[1] > 0]
    icd_freq_pairs_in_cluster_i = icd_freq_pairs_in_cluster_i_nonzeros

    #List[ ((phecode, phenotype), freq) ]
    phecode_phenotype_freq_pairs_in_cluster_i = {}
    for pair in icd_freq_pairs_in_cluster_i:
        icd9 = pair[0]
        freq = pair[1]

        try:
            phecode_phenotype = get_phecode_and_phenotype_from_icd9(icd9)
            
            if phecode_phenotype not in phecode_phenotype_freq_pairs_in_cluster_i:
                phecode_phenotype_freq_pairs_in_cluster_i[phecode_phenotype] = freq
            else:
                phecode_phenotype_freq_pairs_in_cluster_i[phecode_phenotype] += freq
        except:
            pass
        
    return phecode_phenotype_freq_pairs_in_cluster_i

def phecode_dist_from_phecode_freqs(phecode_phenotype_freq_pairs_in_cluster_i):
    phecode_counts = sorted(phecode_phenotype_freq_pairs_in_cluster_i.items(), key=lambda p: p[1], reverse=True)

    #Make list that is plotable
    phecode_distribution = []
    for idx, pair in enumerate(phecode_counts):
        phecode_frequency = pair[1]
        phecode_distribution += [idx] * phecode_frequency
    return phecode_distribution

def cluster_entropy_from_dist(dist):
    counts = Counter(dist)
    counts = [p[1] for p in counts.most_common()]
    return entropy(counts)

# %%
fig = plt.figure(figsize=(20,40))
fig.subplots_adjust(hspace=0.5, wspace=0.5)
fig.suptitle("Phecode Distribution for Clusters 0-49", fontsize=28)

for cluster_i in range(50):
    phecode_phenotype_freq_pairs_in_cluster_i = phecode_distribution_for_cluster_i(cluster_i)
    phecode_dist = phecode_dist_from_phecode_freqs(phecode_phenotype_freq_pairs_in_cluster_i)
    
    e = cluster_entropy_from_dist(phecode_dist)
    
    ax_subplot = fig.add_subplot(10, 5, cluster_i + 1)
    ax_subplot.title.set_text("Cluster {}\n Entropy: {:.4f}".format(cluster_i, e))
    ax_sns = sns.distplot(phecode_dist, kde=False, norm_hist=True)
    ax_sns.set_xticks([])
    
plt.savefig("./tests/phecode_dist_k50_NOT_mc.png")

# %%
#Cluster 38 has the highest entropy, then Cluster 1
ci = 1
phecode_phenotype_freq_pairs_in_cluster_i = phecode_distribution_for_cluster_i(ci)
phecode_dist = phecode_dist_from_phecode_freqs(phecode_phenotype_freq_pairs_in_cluster_i)
e = cluster_entropy_from_dist(phecode_dist)

phecode_counts = sorted(phecode_phenotype_freq_pairs_in_cluster_i.items(), key=lambda p: p[1], reverse=True)
phecode_counts
# Out:
# [(('276', 'Disorders of fluid, electrolyte, and acid-base balance'), 653),
#  (('317', 'Alcohol-related disorders'), 529),
#  (('285', 'Other anemias'), 506),
#  (('296', 'Mood disorders'), 438),
#  (('316', 'Substance addiction and disorders'), 380),
#  (('198', 'Secondary malignant neoplasm'), 369),
#  (('345', 'Epilepsy, recurrent seizures, convulsions'), 329),
#  (('318', 'Tobacco use disorder'), 302),
#  (('300', 'Anxiety disorders'), 272),
#  (('530', 'Diseases of esophagus'), 271),
#  (('480', 'Pneumonia'), 270),
#  (('348', 'Other conditions of brain'), 262),
#  (('250', 'Diabetes mellitus'), 252),
#  (('427', 'Cardiac dysrhythmias'), 250),
#  (('244', 'Hypothyroidism'), 229),
#  (('495', 'Asthma'), 223),
#  (('458', 'Hypotension'), 212),
#  (('509', 'Respiratory failure, insufficiency, arrest'), 206),
#  (('041', 'Bacterial infection NOS'), 193),
#  (('070', 'Viral hepatitis'), 190),
#  (('433', 'Cerebrovascular disease'), 162),
#  (('819', 'Skull and face fracture and other intercranial injury'), 155),
#  (('496', 'Chronic airway obstruction'), 152),
#  (('452', 'Other venous embolism and thrombosis'), 152),
#  (('585', 'Renal failure'), 143),
#  (('591', 'Urinary tract infection'), 141),
#  (('501', 'Pneumonitis due to inhalation of food or vomitus'), 140),
#  (('297', 'Suicidal ideation or attempt'), 134),
#  (('430', 'Intracranial hemorrhage'), 131),
#  (('290', 'Delirium dementia and amnestic and other cognitive disorders'),
#   125),
#  (('743', 'Osteoporosis, osteopenia and pathological fracture'), 118),
#  (('260', 'Protein-calorie malnutrition'), 116),
#  (('038', 'Septicemia'), 115),
#  (('401', 'Hypertension'), 115),
#  (('577', 'Diseases of pancreas'), 113),
#  (('508', 'Pulmonary collapse; interstitial and compensatory emphysema'), 109),
#  (('969', 'Poisoning by psychotropic agents'), 107),
#  (('507', 'Pleurisy; pleural effusion'), 104),
#  (('327', 'Sleep disorders'), 101),
#  (('288', 'Diseases of white blood cells'), 99),
#  (('287', 'Purpura and other hemorrhagic conditions'), 96),
#  (('707', 'Chronic ulcer of skin'), 94),
#  (('783', 'Fever of unknown origin'), 92),
#  (('286', 'Coagulation defects'), 91),
#  (('818', 'Intracranial hemorrhage (injury)'), 90),
#  (('599', 'Other symptoms/disorders or the urinary system'), 89),
#  (('965', 'Poisoning by analgesics, antipyretics, and antirheumatics'), 89),
#  (('278', 'Overweight, obesity and other hyperalimentation'), 88),
#  (('415', 'Pulmonary heart disease'), 83),
#  (('165', 'Cancer within the respiratory system'), 83),
#  (('870', 'Open wounds of head; neck; and trunk'), 81),
#  (('280', 'Iron deficiency anemias'), 79),
#  (('420', 'Carditis'), 78),
#  (('112', 'Candidiasis'), 74),
#  (('573', 'Other disorders of liver'), 74),
#  (('760', 'Back pain'), 70),
#  (('805',
#    'Fracture of vertebral column without mention of spinal cord injury'),
#   70),
#  (('071', 'Human immunodeficiency virus [HIV] disease'), 69),
#  (('479', 'Other upper respiratory disease'), 65),
#  (('292', 'Neurological disorders'), 65),
#  (('338', 'Pain'), 64),
#  (('560', 'Intestinal obstruction without mention of hernia'), 64),
#  (('571', 'Chronic liver disease and cirrhosis'), 64),
#  (('519', 'Other diseases of respiratory system, not elsewhere classified'),
#   64),
#  (('578', 'Gastrointestinal hemorrhage'), 62),
#  (('275', 'Disorders of mineral metabolism'), 62),
#  (('681', 'Superficial cellulitis and abscess'), 60),
#  (('295', 'Schizophrenia and other psychotic disorders'), 60),
#  (('506', 'Empyema and pneumothorax'), 56),
#  (('967',
#    'Adverse effects of sedatives or other central nervous system depressants and anesthetics'),
#   56),
#  (('535', 'Gastritis and duodenitis'), 55),
#  (('411', 'Ischemic Heart Disease'), 55),
#  (('340', 'Migraine'), 53),
#  (('272', 'Disorders of lipoid metabolism'), 53),
#  (('531', 'Peptic ulcer (excl. esophageal)'), 53),
#  (('331', 'Other cerebral degenerations'), 52),
#  (('174', 'Breast cancer'), 52),
#  (('994', 'Sepsis and SIRS'), 52),
#  (('800', 'Fracture of lower limb'), 52),
#  (('081',
#    'Infection/inflammation of internal prosthetic device; implant; and graft'),
#   49),
#  (('253', 'Disorders of the pituitary gland and its hypothalamic control'),
#   48),
#  (('574', 'Cholelithiasis and cholecystitis'), 48),
#  (('284', 'Aplastic anemia'), 47),
#  (('939', 'Atopic/contact dermatitis due to other or unspecified'), 45),
#  (('772', 'Symptoms of the muscles'), 45),
#  (('289', 'Other diseases of blood and blood-forming organs'), 45),
#  (('803', 'Fracture of upper limb'), 44),
#  (('532', 'Dysphagia'), 43),
#  (('807', 'Fracture of ribs'), 43),
#  (('191', 'Manlignant and unknown neoplasms of brain and nervous system'), 43),
#  (('740', 'Osteoarthrosis'), 41),
#  (('342', 'Hemiplegia'), 40),
#  (('850', 'Hemorrhage or hematoma complicating a procedure'), 40),
#  (('960', 'Poisoning by antibiotics'), 40),
#  (('575', 'Other biliary tract disease'), 40),
#  (('958', 'Certain early complications of trauma or procedure'), 40),
#  (('008', 'Intestinal infection'), 39),
#  (('195', 'Cancer, suspected or other'), 39),
#  (('550', 'Abdominal hernia'), 39),
#  (('747', 'Cardiac and circulatory congenital anomalies'), 39),
#  (('315', 'Develomental delays and disorders'), 39),
#  (('916', 'Contusion'), 39),
#  (('990', 'Effects radiation NOS'), 38),
#  (('080', 'Postoperative infection'), 38),
#  (('185', 'Cancer of prostate'), 38),
#  (('189', 'Cancer of urinary organs (incl. kidney and bladder)'), 38),
#  (('510', 'Other diseases of lung'), 37),
#  (('291', 'Other specified nonpsychotic and/or transient mental disorders'),
#   37),
#  (('555', 'Inflammatory bowel disease and other gastroenteritis and colitis'),
#   37),
#  (('395', 'Heart valve disorders'), 36),
#  (('350', 'Abnormal movement'), 36),
#  (('426', 'Cardiac conduction disorders'), 36),
#  (('569', 'Other disorders of intestine'), 35),
#  (('572', 'Ascites (non malignant)'), 34),
#  (('856', 'Vascular complications of surgery and medical procedures'), 34),
#  (('442', 'Other aneurysm'), 34),
#  (('770', 'Myalgia and myositis unspecified'), 33),
#  (('562', 'Diverticulosis and diverticulitis'), 33),
#  (('789', 'Nausea and vomiting'), 33),
#  (('473', 'Diseases of the larynx and vocal cords'), 32),
#  (('962', 'Poisoning by hormones and synthetic substitutes'), 30),
#  (('320', 'Meningitis'), 30),
#  (('963', 'Poisoning by primarily systemic agents'), 29),
#  (('785', 'Abdominal pain'), 29),
#  (('313', 'Pervasive developmental disorders'), 28),
#  (('344', 'Other paralytic syndromes'), 28),
#  (('172', 'Skin cancer'), 28),
#  (('202', 'Cancer of other lymphoid, histiocytic tissue'), 28),
#  (('516', 'Abnormal sputum'), 27),
#  (('722', 'Intervertebral disc disorders'), 27),
#  (('871', 'Open wounds of extremities'), 27),
#  (('714', 'Rheumatoid arthritis and other inflammatory polyarthropathies'),
#   26),
#  (('153', 'Colorectal cancer'), 26),
#  (('966', 'Poisoning by anticonvulsants and anti-Parkinsonism drugs'), 26),
#  (('816', 'Cerebral laceration and contusion'), 26),
#  (('301', 'Personality disorders'), 25),
#  (('567', 'Peritonitis and retroperitoneal infections'), 25),
#  (('334', 'Degenerative disease of the spinal cord'), 25),
#  (('204', 'Leukemia'), 25),
#  (('274', 'Gout and other crystal arthropathies'), 24),
#  (('451', 'Phlebitis and thrombophlebitis'), 24),
#  (('586', 'Other disorders of the kidney and ureters'), 24),
#  (('801', 'Fracture of ankle and foot'), 24),
#  (('830', 'Dislocation'), 24),
#  (('568', 'Other disorders of peritoneum'), 23),
#  (('600', 'Hyperplasia of prostate'), 23),
#  (('594', 'Urinary calculus'), 23),
#  (('593', 'Hematuria'), 23),
#  (('788', 'Syncope and collapse'), 22),
#  (('197', 'Chemotherapy'), 22),
#  (('349', 'Other and unspecified disorders of the nervous system'), 22),
#  (('465',
#    'Acute upper respiratory infections of multiple or unspecified sites'),
#   22),
#  (('536', 'Disorders of function of stomach'), 22),
#  (('149', 'Cancer of larynx, pharynx, nasal cavities'), 22),
#  (('324', 'Other CNS infection and poliomyelitis'), 22),
#  (('365', 'Glaucoma'), 21),
#  (('225', 'Benign neoplasm of brain and other parts of nervous system'), 21),
#  (('200', 'Myeloproliferative disease'), 20),
#  (('854', 'Complications of cardiac/vascular device, implant, and graft'), 20),
#  (('512', 'Other symptoms of respiratory system'), 20),
#  (('721', 'Spondylosis and allied disorders'), 20),
#  (('595', 'Hydronephrosis'), 19),
#  (('356', 'Hereditary and idiopathic peripheral neuropathy'), 19),
#  (('539', 'Bariatric surgery'), 19),
#  (('537', 'Other disorders of stomach and duodenum'), 19),
#  (('710', 'Osteomyelitis, periostitis, and other infections involving bone'),
#   19),
#  (('255', 'Disorders of adrenal glands'), 18),
#  (('505', 'Other pulmonary inflamation or edema'), 17),
#  (('590', 'Pyelonephritis'), 17),
#  (('386', 'Vertiginous syndromes and other disorders of vestibular system'),
#   17),
#  (('155', 'Cancer of liver and intrahepatic bile duct'), 17),
#  (('261', 'Vitamin deficiency'), 17),
#  (('389', 'Hearing loss'), 17),
#  (('802', 'Fracture of pelvis'), 17),
#  (('150', 'Cancer of esophagus'), 17),
#  (('351', 'Other peripheral nerve disorders'), 17),
#  (('745', 'Pain in joint'), 17),
#  (('979', 'Adverse drug events and drug allergies'), 17),
#  (('378', 'Strabismus and other disorders of binocular eye movements'), 17),
#  (('455', 'Hemorrhoids'), 17),
#  (('720', 'Spinal stenosis'), 17),
#  (('323', 'Encephalitis'), 17),
#  (('907', 'Injuries to the nervous system'), 17),
#  (('335', 'Multiple sclerosis'), 16),
#  (('443', 'Peripheral vascular disease'), 16),
#  (('208', 'Benign neoplasm of colon'), 16),
#  (('737', 'Curvature of spine'), 16),
#  (('695', 'Erythematous conditions'), 16),
#  (('558', 'Noninfectious gastroenteritis'), 15),
#  (('790', 'Nonspecific findings on examination of blood'), 15),
#  (('946', 'Anaphylactic shock NOS'), 15),
#  (('136', 'Other infectious and parasitic diseases'), 15),
#  (('771', 'Musculoskeletal symptoms referable to limbs'), 15),
#  (('738', 'Other acquired musculoskeletal deformity'), 15),
#  (('429', 'Ill-defined descriptions and complications of heart disease'), 15),
#  (('428', 'Congestive heart failure; nonhypertensive'), 15),
#  (('333', 'Extrapyramidal disease and abnormal movement disorders'), 15),
#  (('368', 'Visual disturbances'), 15),
#  (('798', 'Malaise and fatigue'), 14),
#  (('564', 'Functional digestive disorders'), 14),
#  (('859', 'Complication due to other implant and internal device'), 14),
#  (('475', 'Chronic sinusitis'), 14),
#  (('596', 'Other disorders of bladder'), 14),
#  (('860', 'Bone marrow or stem cell transplant'), 14),
#  (('649',
#    'Other conditions or status of the mother complicating pregnancy, childbirth, or the puerperium'),
#   14),
#  (('528',
#    'Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue'),
#   14),
#  (('733', 'Other disorders of bone and cartilage'), 14),
#  (('840', 'Sprains and strains'), 14),
#  (('054', 'Herpes simplex'), 13),
#  (('964', 'Poisoning by agents primarily affecting blood constituents'), 13),
#  (('716', 'Other arthropathies'), 13),
#  (('579', 'Other symptoms involving abdomen and pelvis'), 13),
#  (('394', 'Rheumatic disease of the heart valves'), 13),
#  (('270', 'Disorders of protein plasma/amino-acid transport and metabolism'),
#   13),
#  (('513', 'Respiratory abnormalities'), 13),
#  (('961', 'Poisoning by other anti-infectives'), 13),
#  (('441', 'Vascular insufficiency of intestine'), 12),
#  (('218', 'Benign neoplasm of uterus'), 12),
#  (('418', 'Nonspecific chest pain'), 12),
#  (('425', 'Cardiomyopathy'), 12),
#  (('241', 'Nontoxic nodular goiter'), 12),
#  (('343', 'Infantile cerebral palsy'), 12),
#  (('758', 'Chromosomal anomalies and genetic disorders'), 12),
#  (('644', 'Anemia during pregnancy'), 12),
#  (('159',
#    'Malignant neoplasm of other and ill-defined sites within the digestive organs and peritoneum'),
#   12),
#  (('459', 'Other disorders of circulatory system'), 12),
#  (('804', 'Fracture of hand or wrist'), 12),
#  (('782', 'Symptoms involving skin and other integumentary tissue'), 11),
#  (('687', 'Symptoms affecting skin'), 11),
#  (('151', 'Cancer of stomach'), 11),
#  (('251', 'Other disorders of pancreatic internal secretion'), 11),
#  (('352', 'Disorders of other cranial nerves'), 11),
#  (('709', 'Diffuse diseases of connective tissue'), 11),
#  (('972', 'Poisoning by agents primarily affecting the cardiovascular system'),
#   11),
#  (('079', 'Viral infection'), 11),
#  (('282', 'Hereditary hemolytic anemias'), 11),
#  (('303', 'Psychogenic and somatoform disorders'), 11),
#  (('614', 'Inflammatory diseases of female pelvic organs'), 11),
#  (('930', 'Allergic reaction to food'), 11),
#  (('502', 'Postinflammatory pulmonary fibrosis'), 10),
#  (('698', 'Pruritus and related conditions'), 10),
#  (('481', 'Influenza'), 10),
#  (('797', 'Shock'), 10),
#  (('780', 'Hypothermia/Chills'), 10),
#  (('184', 'Cancer of other female genital organs'), 10),
#  (('358', 'Myoneural disorders'), 10),
#  (('809', 'Fracture of unspecified bones'), 10),
#  (('090', 'Sexually transmitted infections (not HIV or hepatitis)'), 10),
#  (('444', 'Arterial embolism and thrombosis'), 10),
#  (('952', 'Spinal cord injury without evidence of spinal bone injury'), 10),
#  (('971',
#    'Poisoning by drugs primarily affecting the autonomic nervous system'),
#   10),
#  (('446', 'Polyarteritis nodosa and allied conditions'), 10),
#  (('145', 'Cancer of mouth'), 10),
#  (('332', "Parkinson's disease"), 9),
#  (('293', 'Symptoms involving head and neck'), 9),
#  (('597', 'Other disorders of urethra and urinary tract'), 9),
#  (('557', 'Intestinal malabsorption (non-celiac)'), 9),
#  (('696', 'Psoriasis and related disorders'), 9),
#  (('304', 'Adjustment reaction'), 9),
#  (('193', 'Thyroid cancer'), 9),
#  (('010', 'Tuberculosis'), 9),
#  (('277', 'Other disorders of metabolism'), 9),
#  (('615', 'Endometriosis'), 9),
#  (('729', 'Other disorders of soft tissues'), 9),
#  (('440', 'Atherosclerosis'), 9),
#  (('580', 'Nephritis; nephrosis; renal sclerosis'), 9),
#  (('305.21', 'Anorexia nervosa'), 8),
#  (('761', 'Cervicalgia'), 8),
#  (('228', 'Hemangioma and lymphangioma, any site'), 8),
#  (('949', 'Allergies, other'), 8),
#  (('180', 'Cervical cancer and dysplasia'), 8),
#  (('337', 'Disorders of the autonomic nervous system'), 8),
#  (('359', 'Muscular dystrophies and other myopathies'), 8),
#  (('750', 'Digestive congenital anomalies'), 8),
#  (('858', 'Complication of internal orthopedic device'), 8),
#  (('117', 'Mycoses'), 8),
#  (('362', 'Other retinal disorders'), 8),
#  (('377', 'Disorders of optic nerve and visual pathways'), 8),
#  (('619', 'Noninflammatory female genital disorders'), 8),
#  (('279', 'Disorders involving the immune mechanism'), 8),
#  (('381', 'Otitis media and Eustachian tube disorders'), 8),
#  (('647', 'Infectious and parasitic complications affecting pregnancy'), 8),
#  (('697', 'Sarcoidosis'), 7),
#  (('477', 'Epistaxis or throat hemorrhage'), 7),
#  (('175', 'Acquired absence of breast'), 7),
#  (('227', 'Benign neoplasm of other endocrine glands and related structures'),
#   7),
#  (('712', 'Infective connective tissue disorders'), 7),
#  (('514', 'Abnormal findings examination of lungs'), 7),
#  (('975',
#    'Poisoning by agents primarily acting on the smooth and skeletal muscles and respiratory system'),
#   7),
#  (('242', 'Thyrotoxicosis with or without goiter'), 7),
#  (('357', 'Inflammatory and toxic neuropathy'), 7),
#  (('369', 'Infection of the eye'), 7),
#  (('626',
#    'Disorders of menstruation and other abnormal bleeding from female genital tract'),
#   7),
#  (('565', 'Anal and rectal conditions'), 7),
#  (('727', 'Other disorders of synovium, tendon, and bursa'), 7),
#  (('522', 'Diseases of pulp and periapical tissues'), 6),
#  (('212', 'Benign neoplasm of respiratory and intrathoracic organs'), 6),
#  (('374', 'Other disorders of eyelids'), 6),
#  (('628', 'Ovarian cyst'), 6),
#  (('182', 'Malignant neoplasm of uterus'), 6),
#  (('483', 'Acute bronchitis and bronchiolitis'), 6),
#  (('817', 'Concussion'), 6),
#  (('157', 'Pancreatic cancer'), 6),
#  (('252', 'Disorders of parathyroid gland'), 6),
#  (('355', 'Complex regional/central pain syndrome'), 6),
#  (('367',
#    'Disorders of refraction and accommodation; blindness and low vision'),
#   6),
#  (('752', 'Nervous system congenital anomalies'), 6),
#  (('110', 'Dermatophytosis / Dermatomycosis'), 6),
#  (('199', 'Neoplasm of uncertain behavior'), 6),
#  (('306', 'Other mental disorder'), 6),
#  (('642',
#    'Hypertension complicating pregnancy, childbirth, and the puerperium'),
#   6),
#  (('671',
#    'Venous/cerebrovascular complications embolism in pregnancy and the puerperium'),
#   6),
#  (('561', 'Symptoms involving digestive system'), 6),
#  (('749', 'Congenital anomalies of face and neck'), 6),
#  (('981',
#    'Toxic effect of (non-ethyl) alcohol and petroleum and other solvents'),
#   6),
#  (('454', 'Varicose veins'), 5),
#  (('503', 'Pulmonary congestion and hypostasis'), 5),
#  (('559', 'Ileostomy status'), 5),
#  (('457',
#    'Encounter for long-term (current) use of anticoagulants, antithrombotics, aspirin'),
#   5),
#  (('305.2', 'Eating disorder'), 5),
#  (('504', 'Other alveolar and parietoalveolar pneumonopathy'), 5),
#  (('735', 'Acquired foot deformities'), 5),
#  (('587', 'Kidney replaced by transpant'), 5),
#  (('447', 'Other disorders of arteries and arterioles'), 5),
#  (('474', 'Acute and chronic tonsillitis'), 5),
#  (('741', 'Symptoms and disorders of the joints'), 5),
#  (('942', 'Infusion and transfusion reaction'), 5),
#  (('366', 'Cataract'), 5),
#  (('523', 'Gingival and periodontal diseases'), 5),
#  (('726', 'Peripheral enthesopathies and allied syndromes'), 5),
#  (('872', 'Traumatic amputation'), 5),
#  (('201', "Hodgkin's disease"), 5),
#  (('379', 'Other disorders of eye'), 4),
#  (('456', 'Chronic venous insufficiency [CVI]'), 4),
#  (('717', 'Polymyalgia Rheumatica'), 4),
#  (('855', 'Complication of nervous system device, implant, and graft'), 4),
#  (('053', 'Herpes zoster'), 4),
#  (('211', 'Benign neoplasm of other parts of digestive system'), 4),
#  (('414', 'Other forms of chronic heart disease'), 4),
#  (('476', 'Allergic rhinitis'), 4),
#  (('521', 'Diseases of hard tissues of teeth'), 4),
#  (('608', 'Other disorders of male genital organs'), 4),
#  (('748', 'Anomalies of respiratory system, congenital'), 4),
#  (('131', 'Protozoan infection'), 4),
#  (('170', 'Cancer of bone and connective tissue'), 4),
#  (('271', 'Disorders of carbohydrate transport and metabolism'), 4),
#  (('341', 'Other demyelinating diseases of central nervous system'), 4),
#  (('500', 'Lung disease due to external agents'), 4),
#  (('526', 'Diseases of the jaws'), 4),
#  (('556', 'Ulceration of the lower GI tract'), 4),
#  (('627', 'Menopausal and postmenopausal disorders'), 4),
#  (('947', 'Urticaria'), 4),
#  (('711', 'Arthropathy associated with infections'), 4),
#  (('754', 'Congenital musculoskeletal deformities of spine'), 4),
#  (('132', 'Infestation (lice, mites)'), 4),
#  (('686', 'Other local infections of skin and subcutaneous tissue'), 4),
#  (('701', 'Other hypertrophic and atrophic conditions of skin'), 4),
#  (('728', 'Disorders of muscle, ligament, and fascia'), 4),
#  (('983', 'Toxic effect of corrosive aromatics, acids, and caustic alkalis'),
#   4),
#  (('245', 'Thyroiditis'), 3),
#  (('464', 'Acute sinusitis'), 3),
#  (('264', 'Lack of normal physiological development'), 3),
#  (('396', 'Abnormal heart sounds'), 3),
#  (('791', 'Gangrene'), 3),
#  (('875', 'Non-healing surgical wound'), 3),
#  (('164', 'Cancer of intrathoracic organs'), 3),
#  (('258', 'Iatrogenic endocrine disorders'), 3),
#  (('283', 'Acquired hemolytic anemias'), 3),
#  (('372', 'Disorders of conjunctiva'), 3),
#  (('450', 'Noninfectious disorders of lymphatic channels'), 3),
#  (('520', 'Disorders of tooth development'), 3),
#  (('588', 'Disorders resulting from impaired renal function'), 3),
#  (('634', 'Miscarriage; stillbirth'), 3),
#  (('706', 'Diseases of sebaceous glands'), 3),
#  (('724', 'Other and unspecified disorders of back'), 3),
#  (('751', 'Genitourinary congenital anomalies'), 3),
#  (('781', 'Symptoms involving nervous and musculoskeletal systems'), 3),
#  (('281', 'Other deficiency anemia'), 3),
#  (('371', 'Inflammation of the eye'), 3),
#  (('382', 'Otalgia'), 3),
#  (('529', 'Diseases and other conditions of the tongue'), 3),
#  (('635', 'Hemorrhage during pregnancy; childbirth and postpartum'), 3),
#  (('759', 'Other and unspecified congenital anomalies'), 3),
#  (('973',
#    'Poisoning by agents primarily affecting the gastrointestinal system'),
#   3),
#  (('974', 'Poisoning by water, mineral, and uric acid metabolism drugs'), 3),
#  (('213', 'Benign neoplasm of bone and articular cartilage'), 2),
#  (('240', 'Simple and unspecified goiter'), 2),
#  (('249', 'Secondary diabetes mellitus'), 2),
#  (('325', 'Phlebitis and thrombophlebitis of intracranial venous sinuses'), 2),
#  (('385', 'Other disorders of middle ear and mastoid'), 2),
#  (('416', 'Cardiomegaly'), 2),
#  (('540', 'Appendiceal conditions'), 2),
#  (('853', 'Complication of colostomy or enterostomy'), 2),
#  (('601', 'Inflammatory diseases of prostate'), 2),
#  (('605', 'Erectile dysfunction [ED]'), 2),
#  (('625', 'Pain and other symptoms associated with female genital organs'), 2),
#  (('674', 'Other complications of the puerperium NEC'), 2),
#  (('689', 'Disorder of skin and subcutaneous tissue NOS'), 2),
#  (('765', 'Cervical radiculitis'), 2),
#  (('764', 'Sciatica'), 2),
#  (('269', 'Proteinuria'), 2),
#  (('611', 'Abnormal findings on mammogram or breast exam'), 2),
#  (('989',
#    'Toxic effect of other substances, chiefly nonmedicinal as to source'),
#   2),
#  (('857',
#    'Mechanical complication of unspecified genitourinary device, implant, and graft'),
#   2),
#  (('187', 'Cancer of other male genital organs'), 2),
#  (('977', 'Personal history of allergy to medicinal agents'), 2),
#  (('078', 'Viral warts & HPV'), 2),
#  (('158', 'Neoplasm of unspecified nature of digestive system'), 2),
#  (('256', 'Ovarian dysfunction'), 2),
#  (('259', 'Other endocrine disorders'), 2),
#  (('302', 'Sexual and gender identity disorders'), 2),
#  (('353', 'Nerve root and plexus disorders'), 2),
#  (('592', 'Cystitis and urethritis'), 2),
#  (('624', 'Symptoms involving female genital tract'), 2),
#  (('669', 'Complications of labor and delivery NEC'), 2),
#  (('702', 'Degenerative skin conditions and other dermatoses'), 2),
#  (('704', 'Diseases of hair and hair follicles'), 2),
#  (('723', 'Other disorders of cervical region'), 2),
#  (('731',
#    'Osteitis deformans and osteopathies associated with other disorders classified elsewhere'),
#   2),
#  (('976',
#    'Poisoning by agents primarily affecting skin & mucous membrane, ophthalmological, otorhinolaryngological, & dental drugs'),
#   2),
#  (('851', 'Complications of transplants and reattached limbs'), 2),
#  (('031', 'Diseases due to other mycobacteria'), 1),
#  (('133', 'Arthropod-borne diseases'), 1),
#  (('134', 'Helminthiases'), 1),
#  (('230', "Kaposi's sarcoma"), 1),
#  (('194', 'Cancer of other endocrine glands'), 1),
#  (('220', 'Benign neoplasm of ovary'), 1),
#  (('221', 'Benign neoplasm of other female genital organs'), 1),
#  (('223', 'Benign neoplasm of kidney and other urinary organs'), 1),
#  (('257', 'Testicular dysfunction'), 1),
#  (('312', 'Conduct disorders'), 1),
#  (('339', 'Other headache syndromes'), 1),
#  (('364', 'Corneal opacity and other disorders of cornea'), 1),
#  (('376', 'Disorders of the orbit'), 1),
#  (('448', 'Disease of capillaries'), 1),
#  (('472', 'Chronic pharyngitis and nasopharyngitis'), 1),
#  (('497', 'Bronchitis'), 1),
#  (('498', 'Acute bronchospasm'), 1),
#  (('527', 'Diseases of the salivary glands'), 1),
#  (('602', 'Other disorders of prostate'), 1),
#  (('603', 'Other disorders of testis'), 1),
#  (('604', 'Disorders of penis'), 1),
#  (('613', 'Other nonmalignant breast conditions'), 1),
#  (('636', 'Early or threatened labor; hemorrhage in early pregnancy'), 1),
#  (('646', 'Other complications of pregnancy NEC'), 1),
#  (('655',
#    'Known or suspected fetal abnormality affecting management of mother'),
#   1),
#  (('690', 'Erythematosquamous dermatosis'), 1),
#  (('931', 'Contact dermatitis and other eczema due to plants [except food]'),
#   1),
#  (('705', 'Disorders of sweat glands'), 1),
#  (('694', 'Dyschromia and Vitiligo'), 1),
#  (('713', 'Arthropathy associated with other disorders classified elsewhere'),
#   1),
#  (('739', 'Contracture of joint'), 1),
#  (('742', 'Derangement of joint, non-traumatic'), 1),
#  (('715', 'Other inflammatory spondylopathies'), 1),
#  (('763', 'Thoracic or lumbosacral neuritis or radiculitis, unspecified'), 1),
#  (('766', 'Neuralgia, neuritis, and radiculitis NOS'), 1),
#  (('732', 'Osteochondropathies'), 1),
#  (('736', 'Other acquired deformities of limbs'), 1),
#  (('756', 'Other congenital musculoskeletal anomalies'), 1),
#  (('478', 'Throat pain'), 1),
#  (('346', 'Abnormal findings on study of brain and/or nervous system'), 1),
#  (('589', 'Abnormal results of function study of kidney'), 1),
#  (('246', 'Other disorders of thyroid'), 1),
#  (('841', 'Sprains and strains of back and neck'), 1),
#  (('874', 'Complication of amputation stump'), 1),
#  (('980', 'Encounter for long-term (current) use of antibiotics'), 1)]

# %%
# Out:
# 100%|██████████| 50/50 [02:09<00:00,  2.60s/it]

# %%
# Out:
# 13
# dict_values([11, 5, 7, 11, 2, 3, 2, 1, 1, 1, 3, 2, 1])
# 50

# %%
phecode_counts
# Out:
# [(('276', 'Disorders of fluid, electrolyte, and acid-base balance'), 653),
#  (('317', 'Alcohol-related disorders'), 529),
#  (('285', 'Other anemias'), 506),
#  (('296', 'Mood disorders'), 438),
#  (('316', 'Substance addiction and disorders'), 380),
#  (('198', 'Secondary malignant neoplasm'), 369),
#  (('345', 'Epilepsy, recurrent seizures, convulsions'), 329),
#  (('318', 'Tobacco use disorder'), 302),
#  (('300', 'Anxiety disorders'), 272),
#  (('530', 'Diseases of esophagus'), 271),
#  (('480', 'Pneumonia'), 270),
#  (('348', 'Other conditions of brain'), 262),
#  (('250', 'Diabetes mellitus'), 252),
#  (('427', 'Cardiac dysrhythmias'), 250),
#  (('244', 'Hypothyroidism'), 229),
#  (('495', 'Asthma'), 223),
#  (('458', 'Hypotension'), 212),
#  (('509', 'Respiratory failure, insufficiency, arrest'), 206),
#  (('041', 'Bacterial infection NOS'), 193),
#  (('070', 'Viral hepatitis'), 190),
#  (('433', 'Cerebrovascular disease'), 162),
#  (('819', 'Skull and face fracture and other intercranial injury'), 155),
#  (('496', 'Chronic airway obstruction'), 152),
#  (('452', 'Other venous embolism and thrombosis'), 152),
#  (('585', 'Renal failure'), 143),
#  (('591', 'Urinary tract infection'), 141),
#  (('501', 'Pneumonitis due to inhalation of food or vomitus'), 140),
#  (('297', 'Suicidal ideation or attempt'), 134),
#  (('430', 'Intracranial hemorrhage'), 131),
#  (('290', 'Delirium dementia and amnestic and other cognitive disorders'),
#   125),
#  (('743', 'Osteoporosis, osteopenia and pathological fracture'), 118),
#  (('260', 'Protein-calorie malnutrition'), 116),
#  (('038', 'Septicemia'), 115),
#  (('401', 'Hypertension'), 115),
#  (('577', 'Diseases of pancreas'), 113),
#  (('508', 'Pulmonary collapse; interstitial and compensatory emphysema'), 109),
#  (('969', 'Poisoning by psychotropic agents'), 107),
#  (('507', 'Pleurisy; pleural effusion'), 104),
#  (('327', 'Sleep disorders'), 101),
#  (('288', 'Diseases of white blood cells'), 99),
#  (('287', 'Purpura and other hemorrhagic conditions'), 96),
#  (('707', 'Chronic ulcer of skin'), 94),
#  (('783', 'Fever of unknown origin'), 92),
#  (('286', 'Coagulation defects'), 91),
#  (('818', 'Intracranial hemorrhage (injury)'), 90),
#  (('599', 'Other symptoms/disorders or the urinary system'), 89),
#  (('965', 'Poisoning by analgesics, antipyretics, and antirheumatics'), 89),
#  (('278', 'Overweight, obesity and other hyperalimentation'), 88),
#  (('415', 'Pulmonary heart disease'), 83),
#  (('165', 'Cancer within the respiratory system'), 83),
#  (('870', 'Open wounds of head; neck; and trunk'), 81),
#  (('280', 'Iron deficiency anemias'), 79),
#  (('420', 'Carditis'), 78),
#  (('112', 'Candidiasis'), 74),
#  (('573', 'Other disorders of liver'), 74),
#  (('760', 'Back pain'), 70),
#  (('805',
#    'Fracture of vertebral column without mention of spinal cord injury'),
#   70),
#  (('071', 'Human immunodeficiency virus [HIV] disease'), 69),
#  (('479', 'Other upper respiratory disease'), 65),
#  (('292', 'Neurological disorders'), 65),
#  (('338', 'Pain'), 64),
#  (('560', 'Intestinal obstruction without mention of hernia'), 64),
#  (('571', 'Chronic liver disease and cirrhosis'), 64),
#  (('519', 'Other diseases of respiratory system, not elsewhere classified'),
#   64),
#  (('578', 'Gastrointestinal hemorrhage'), 62),
#  (('275', 'Disorders of mineral metabolism'), 62),
#  (('681', 'Superficial cellulitis and abscess'), 60),
#  (('295', 'Schizophrenia and other psychotic disorders'), 60),
#  (('506', 'Empyema and pneumothorax'), 56),
#  (('967',
#    'Adverse effects of sedatives or other central nervous system depressants and anesthetics'),
#   56),
#  (('535', 'Gastritis and duodenitis'), 55),
#  (('411', 'Ischemic Heart Disease'), 55),
#  (('340', 'Migraine'), 53),
#  (('272', 'Disorders of lipoid metabolism'), 53),
#  (('531', 'Peptic ulcer (excl. esophageal)'), 53),
#  (('331', 'Other cerebral degenerations'), 52),
#  (('174', 'Breast cancer'), 52),
#  (('994', 'Sepsis and SIRS'), 52),
#  (('800', 'Fracture of lower limb'), 52),
#  (('081',
#    'Infection/inflammation of internal prosthetic device; implant; and graft'),
#   49),
#  (('253', 'Disorders of the pituitary gland and its hypothalamic control'),
#   48),
#  (('574', 'Cholelithiasis and cholecystitis'), 48),
#  (('284', 'Aplastic anemia'), 47),
#  (('939', 'Atopic/contact dermatitis due to other or unspecified'), 45),
#  (('772', 'Symptoms of the muscles'), 45),
#  (('289', 'Other diseases of blood and blood-forming organs'), 45),
#  (('803', 'Fracture of upper limb'), 44),
#  (('532', 'Dysphagia'), 43),
#  (('807', 'Fracture of ribs'), 43),
#  (('191', 'Manlignant and unknown neoplasms of brain and nervous system'), 43),
#  (('740', 'Osteoarthrosis'), 41),
#  (('342', 'Hemiplegia'), 40),
#  (('850', 'Hemorrhage or hematoma complicating a procedure'), 40),
#  (('960', 'Poisoning by antibiotics'), 40),
#  (('575', 'Other biliary tract disease'), 40),
#  (('958', 'Certain early complications of trauma or procedure'), 40),
#  (('008', 'Intestinal infection'), 39),
#  (('195', 'Cancer, suspected or other'), 39),
#  (('550', 'Abdominal hernia'), 39),
#  (('747', 'Cardiac and circulatory congenital anomalies'), 39),
#  (('315', 'Develomental delays and disorders'), 39),
#  (('916', 'Contusion'), 39),
#  (('990', 'Effects radiation NOS'), 38),
#  (('080', 'Postoperative infection'), 38),
#  (('185', 'Cancer of prostate'), 38),
#  (('189', 'Cancer of urinary organs (incl. kidney and bladder)'), 38),
#  (('510', 'Other diseases of lung'), 37),
#  (('291', 'Other specified nonpsychotic and/or transient mental disorders'),
#   37),
#  (('555', 'Inflammatory bowel disease and other gastroenteritis and colitis'),
#   37),
#  (('395', 'Heart valve disorders'), 36),
#  (('350', 'Abnormal movement'), 36),
#  (('426', 'Cardiac conduction disorders'), 36),
#  (('569', 'Other disorders of intestine'), 35),
#  (('572', 'Ascites (non malignant)'), 34),
#  (('856', 'Vascular complications of surgery and medical procedures'), 34),
#  (('442', 'Other aneurysm'), 34),
#  (('770', 'Myalgia and myositis unspecified'), 33),
#  (('562', 'Diverticulosis and diverticulitis'), 33),
#  (('789', 'Nausea and vomiting'), 33),
#  (('473', 'Diseases of the larynx and vocal cords'), 32),
#  (('962', 'Poisoning by hormones and synthetic substitutes'), 30),
#  (('320', 'Meningitis'), 30),
#  (('963', 'Poisoning by primarily systemic agents'), 29),
#  (('785', 'Abdominal pain'), 29),
#  (('313', 'Pervasive developmental disorders'), 28),
#  (('344', 'Other paralytic syndromes'), 28),
#  (('172', 'Skin cancer'), 28),
#  (('202', 'Cancer of other lymphoid, histiocytic tissue'), 28),
#  (('516', 'Abnormal sputum'), 27),
#  (('722', 'Intervertebral disc disorders'), 27),
#  (('871', 'Open wounds of extremities'), 27),
#  (('714', 'Rheumatoid arthritis and other inflammatory polyarthropathies'),
#   26),
#  (('153', 'Colorectal cancer'), 26),
#  (('966', 'Poisoning by anticonvulsants and anti-Parkinsonism drugs'), 26),
#  (('816', 'Cerebral laceration and contusion'), 26),
#  (('301', 'Personality disorders'), 25),
#  (('567', 'Peritonitis and retroperitoneal infections'), 25),
#  (('334', 'Degenerative disease of the spinal cord'), 25),
#  (('204', 'Leukemia'), 25),
#  (('274', 'Gout and other crystal arthropathies'), 24),
#  (('451', 'Phlebitis and thrombophlebitis'), 24),
#  (('586', 'Other disorders of the kidney and ureters'), 24),
#  (('801', 'Fracture of ankle and foot'), 24),
#  (('830', 'Dislocation'), 24),
#  (('568', 'Other disorders of peritoneum'), 23),
#  (('600', 'Hyperplasia of prostate'), 23),
#  (('594', 'Urinary calculus'), 23),
#  (('593', 'Hematuria'), 23),
#  (('788', 'Syncope and collapse'), 22),
#  (('197', 'Chemotherapy'), 22),
#  (('349', 'Other and unspecified disorders of the nervous system'), 22),
#  (('465',
#    'Acute upper respiratory infections of multiple or unspecified sites'),
#   22),
#  (('536', 'Disorders of function of stomach'), 22),
#  (('149', 'Cancer of larynx, pharynx, nasal cavities'), 22),
#  (('324', 'Other CNS infection and poliomyelitis'), 22),
#  (('365', 'Glaucoma'), 21),
#  (('225', 'Benign neoplasm of brain and other parts of nervous system'), 21),
#  (('200', 'Myeloproliferative disease'), 20),
#  (('854', 'Complications of cardiac/vascular device, implant, and graft'), 20),
#  (('512', 'Other symptoms of respiratory system'), 20),
#  (('721', 'Spondylosis and allied disorders'), 20),
#  (('595', 'Hydronephrosis'), 19),
#  (('356', 'Hereditary and idiopathic peripheral neuropathy'), 19),
#  (('539', 'Bariatric surgery'), 19),
#  (('537', 'Other disorders of stomach and duodenum'), 19),
#  (('710', 'Osteomyelitis, periostitis, and other infections involving bone'),
#   19),
#  (('255', 'Disorders of adrenal glands'), 18),
#  (('505', 'Other pulmonary inflamation or edema'), 17),
#  (('590', 'Pyelonephritis'), 17),
#  (('386', 'Vertiginous syndromes and other disorders of vestibular system'),
#   17),
#  (('155', 'Cancer of liver and intrahepatic bile duct'), 17),
#  (('261', 'Vitamin deficiency'), 17),
#  (('389', 'Hearing loss'), 17),
#  (('802', 'Fracture of pelvis'), 17),
#  (('150', 'Cancer of esophagus'), 17),
#  (('351', 'Other peripheral nerve disorders'), 17),
#  (('745', 'Pain in joint'), 17),
#  (('979', 'Adverse drug events and drug allergies'), 17),
#  (('378', 'Strabismus and other disorders of binocular eye movements'), 17),
#  (('455', 'Hemorrhoids'), 17),
#  (('720', 'Spinal stenosis'), 17),
#  (('323', 'Encephalitis'), 17),
#  (('907', 'Injuries to the nervous system'), 17),
#  (('335', 'Multiple sclerosis'), 16),
#  (('443', 'Peripheral vascular disease'), 16),
#  (('208', 'Benign neoplasm of colon'), 16),
#  (('737', 'Curvature of spine'), 16),
#  (('695', 'Erythematous conditions'), 16),
#  (('558', 'Noninfectious gastroenteritis'), 15),
#  (('790', 'Nonspecific findings on examination of blood'), 15),
#  (('946', 'Anaphylactic shock NOS'), 15),
#  (('136', 'Other infectious and parasitic diseases'), 15),
#  (('771', 'Musculoskeletal symptoms referable to limbs'), 15),
#  (('738', 'Other acquired musculoskeletal deformity'), 15),
#  (('429', 'Ill-defined descriptions and complications of heart disease'), 15),
#  (('428', 'Congestive heart failure; nonhypertensive'), 15),
#  (('333', 'Extrapyramidal disease and abnormal movement disorders'), 15),
#  (('368', 'Visual disturbances'), 15),
#  (('798', 'Malaise and fatigue'), 14),
#  (('564', 'Functional digestive disorders'), 14),
#  (('859', 'Complication due to other implant and internal device'), 14),
#  (('475', 'Chronic sinusitis'), 14),
#  (('596', 'Other disorders of bladder'), 14),
#  (('860', 'Bone marrow or stem cell transplant'), 14),
#  (('649',
#    'Other conditions or status of the mother complicating pregnancy, childbirth, or the puerperium'),
#   14),
#  (('528',
#    'Diseases of the oral soft tissues, excluding lesions specific for gingiva and tongue'),
#   14),
#  (('733', 'Other disorders of bone and cartilage'), 14),
#  (('840', 'Sprains and strains'), 14),
#  (('054', 'Herpes simplex'), 13),
#  (('964', 'Poisoning by agents primarily affecting blood constituents'), 13),
#  (('716', 'Other arthropathies'), 13),
#  (('579', 'Other symptoms involving abdomen and pelvis'), 13),
#  (('394', 'Rheumatic disease of the heart valves'), 13),
#  (('270', 'Disorders of protein plasma/amino-acid transport and metabolism'),
#   13),
#  (('513', 'Respiratory abnormalities'), 13),
#  (('961', 'Poisoning by other anti-infectives'), 13),
#  (('441', 'Vascular insufficiency of intestine'), 12),
#  (('218', 'Benign neoplasm of uterus'), 12),
#  (('418', 'Nonspecific chest pain'), 12),
#  (('425', 'Cardiomyopathy'), 12),
#  (('241', 'Nontoxic nodular goiter'), 12),
#  (('343', 'Infantile cerebral palsy'), 12),
#  (('758', 'Chromosomal anomalies and genetic disorders'), 12),
#  (('644', 'Anemia during pregnancy'), 12),
#  (('159',
#    'Malignant neoplasm of other and ill-defined sites within the digestive organs and peritoneum'),
#   12),
#  (('459', 'Other disorders of circulatory system'), 12),
#  (('804', 'Fracture of hand or wrist'), 12),
#  (('782', 'Symptoms involving skin and other integumentary tissue'), 11),
#  (('687', 'Symptoms affecting skin'), 11),
#  (('151', 'Cancer of stomach'), 11),
#  (('251', 'Other disorders of pancreatic internal secretion'), 11),
#  (('352', 'Disorders of other cranial nerves'), 11),
#  (('709', 'Diffuse diseases of connective tissue'), 11),
#  (('972', 'Poisoning by agents primarily affecting the cardiovascular system'),
#   11),
#  (('079', 'Viral infection'), 11),
#  (('282', 'Hereditary hemolytic anemias'), 11),
#  (('303', 'Psychogenic and somatoform disorders'), 11),
#  (('614', 'Inflammatory diseases of female pelvic organs'), 11),
#  (('930', 'Allergic reaction to food'), 11),
#  (('502', 'Postinflammatory pulmonary fibrosis'), 10),
#  (('698', 'Pruritus and related conditions'), 10),
#  (('481', 'Influenza'), 10),
#  (('797', 'Shock'), 10),
#  (('780', 'Hypothermia/Chills'), 10),
#  (('184', 'Cancer of other female genital organs'), 10),
#  (('358', 'Myoneural disorders'), 10),
#  (('809', 'Fracture of unspecified bones'), 10),
#  (('090', 'Sexually transmitted infections (not HIV or hepatitis)'), 10),
#  (('444', 'Arterial embolism and thrombosis'), 10),
#  (('952', 'Spinal cord injury without evidence of spinal bone injury'), 10),
#  (('971',
#    'Poisoning by drugs primarily affecting the autonomic nervous system'),
#   10),
#  (('446', 'Polyarteritis nodosa and allied conditions'), 10),
#  (('145', 'Cancer of mouth'), 10),
#  (('332', "Parkinson's disease"), 9),
#  (('293', 'Symptoms involving head and neck'), 9),
#  (('597', 'Other disorders of urethra and urinary tract'), 9),
#  (('557', 'Intestinal malabsorption (non-celiac)'), 9),
#  (('696', 'Psoriasis and related disorders'), 9),
#  (('304', 'Adjustment reaction'), 9),
#  (('193', 'Thyroid cancer'), 9),
#  (('010', 'Tuberculosis'), 9),
#  (('277', 'Other disorders of metabolism'), 9),
#  (('615', 'Endometriosis'), 9),
#  (('729', 'Other disorders of soft tissues'), 9),
#  (('440', 'Atherosclerosis'), 9),
#  (('580', 'Nephritis; nephrosis; renal sclerosis'), 9),
#  (('305.21', 'Anorexia nervosa'), 8),
#  (('761', 'Cervicalgia'), 8),
#  (('228', 'Hemangioma and lymphangioma, any site'), 8),
#  (('949', 'Allergies, other'), 8),
#  (('180', 'Cervical cancer and dysplasia'), 8),
#  (('337', 'Disorders of the autonomic nervous system'), 8),
#  (('359', 'Muscular dystrophies and other myopathies'), 8),
#  (('750', 'Digestive congenital anomalies'), 8),
#  (('858', 'Complication of internal orthopedic device'), 8),
#  (('117', 'Mycoses'), 8),
#  (('362', 'Other retinal disorders'), 8),
#  (('377', 'Disorders of optic nerve and visual pathways'), 8),
#  (('619', 'Noninflammatory female genital disorders'), 8),
#  (('279', 'Disorders involving the immune mechanism'), 8),
#  (('381', 'Otitis media and Eustachian tube disorders'), 8),
#  (('647', 'Infectious and parasitic complications affecting pregnancy'), 8),
#  (('697', 'Sarcoidosis'), 7),
#  (('477', 'Epistaxis or throat hemorrhage'), 7),
#  (('175', 'Acquired absence of breast'), 7),
#  (('227', 'Benign neoplasm of other endocrine glands and related structures'),
#   7),
#  (('712', 'Infective connective tissue disorders'), 7),
#  (('514', 'Abnormal findings examination of lungs'), 7),
#  (('975',
#    'Poisoning by agents primarily acting on the smooth and skeletal muscles and respiratory system'),
#   7),
#  (('242', 'Thyrotoxicosis with or without goiter'), 7),
#  (('357', 'Inflammatory and toxic neuropathy'), 7),
#  (('369', 'Infection of the eye'), 7),
#  (('626',
#    'Disorders of menstruation and other abnormal bleeding from female genital tract'),
#   7),
#  (('565', 'Anal and rectal conditions'), 7),
#  (('727', 'Other disorders of synovium, tendon, and bursa'), 7),
#  (('522', 'Diseases of pulp and periapical tissues'), 6),
#  (('212', 'Benign neoplasm of respiratory and intrathoracic organs'), 6),
#  (('374', 'Other disorders of eyelids'), 6),
#  (('628', 'Ovarian cyst'), 6),
#  (('182', 'Malignant neoplasm of uterus'), 6),
#  (('483', 'Acute bronchitis and bronchiolitis'), 6),
#  (('817', 'Concussion'), 6),
#  (('157', 'Pancreatic cancer'), 6),
#  (('252', 'Disorders of parathyroid gland'), 6),
#  (('355', 'Complex regional/central pain syndrome'), 6),
#  (('367',
#    'Disorders of refraction and accommodation; blindness and low vision'),
#   6),
#  (('752', 'Nervous system congenital anomalies'), 6),
#  (('110', 'Dermatophytosis / Dermatomycosis'), 6),
#  (('199', 'Neoplasm of uncertain behavior'), 6),
#  (('306', 'Other mental disorder'), 6),
#  (('642',
#    'Hypertension complicating pregnancy, childbirth, and the puerperium'),
#   6),
#  (('671',
#    'Venous/cerebrovascular complications embolism in pregnancy and the puerperium'),
#   6),
#  (('561', 'Symptoms involving digestive system'), 6),
#  (('749', 'Congenital anomalies of face and neck'), 6),
#  (('981',
#    'Toxic effect of (non-ethyl) alcohol and petroleum and other solvents'),
#   6),
#  (('454', 'Varicose veins'), 5),
#  (('503', 'Pulmonary congestion and hypostasis'), 5),
#  (('559', 'Ileostomy status'), 5),
#  (('457',
#    'Encounter for long-term (current) use of anticoagulants, antithrombotics, aspirin'),
#   5),
#  (('305.2', 'Eating disorder'), 5),
#  (('504', 'Other alveolar and parietoalveolar pneumonopathy'), 5),
#  (('735', 'Acquired foot deformities'), 5),
#  (('587', 'Kidney replaced by transpant'), 5),
#  (('447', 'Other disorders of arteries and arterioles'), 5),
#  (('474', 'Acute and chronic tonsillitis'), 5),
#  (('741', 'Symptoms and disorders of the joints'), 5),
#  (('942', 'Infusion and transfusion reaction'), 5),
#  (('366', 'Cataract'), 5),
#  (('523', 'Gingival and periodontal diseases'), 5),
#  (('726', 'Peripheral enthesopathies and allied syndromes'), 5),
#  (('872', 'Traumatic amputation'), 5),
#  (('201', "Hodgkin's disease"), 5),
#  (('379', 'Other disorders of eye'), 4),
#  (('456', 'Chronic venous insufficiency [CVI]'), 4),
#  (('717', 'Polymyalgia Rheumatica'), 4),
#  (('855', 'Complication of nervous system device, implant, and graft'), 4),
#  (('053', 'Herpes zoster'), 4),
#  (('211', 'Benign neoplasm of other parts of digestive system'), 4),
#  (('414', 'Other forms of chronic heart disease'), 4),
#  (('476', 'Allergic rhinitis'), 4),
#  (('521', 'Diseases of hard tissues of teeth'), 4),
#  (('608', 'Other disorders of male genital organs'), 4),
#  (('748', 'Anomalies of respiratory system, congenital'), 4),
#  (('131', 'Protozoan infection'), 4),
#  (('170', 'Cancer of bone and connective tissue'), 4),
#  (('271', 'Disorders of carbohydrate transport and metabolism'), 4),
#  (('341', 'Other demyelinating diseases of central nervous system'), 4),
#  (('500', 'Lung disease due to external agents'), 4),
#  (('526', 'Diseases of the jaws'), 4),
#  (('556', 'Ulceration of the lower GI tract'), 4),
#  (('627', 'Menopausal and postmenopausal disorders'), 4),
#  (('947', 'Urticaria'), 4),
#  (('711', 'Arthropathy associated with infections'), 4),
#  (('754', 'Congenital musculoskeletal deformities of spine'), 4),
#  (('132', 'Infestation (lice, mites)'), 4),
#  (('686', 'Other local infections of skin and subcutaneous tissue'), 4),
#  (('701', 'Other hypertrophic and atrophic conditions of skin'), 4),
#  (('728', 'Disorders of muscle, ligament, and fascia'), 4),
#  (('983', 'Toxic effect of corrosive aromatics, acids, and caustic alkalis'),
#   4),
#  (('245', 'Thyroiditis'), 3),
#  (('464', 'Acute sinusitis'), 3),
#  (('264', 'Lack of normal physiological development'), 3),
#  (('396', 'Abnormal heart sounds'), 3),
#  (('791', 'Gangrene'), 3),
#  (('875', 'Non-healing surgical wound'), 3),
#  (('164', 'Cancer of intrathoracic organs'), 3),
#  (('258', 'Iatrogenic endocrine disorders'), 3),
#  (('283', 'Acquired hemolytic anemias'), 3),
#  (('372', 'Disorders of conjunctiva'), 3),
#  (('450', 'Noninfectious disorders of lymphatic channels'), 3),
#  (('520', 'Disorders of tooth development'), 3),
#  (('588', 'Disorders resulting from impaired renal function'), 3),
#  (('634', 'Miscarriage; stillbirth'), 3),
#  (('706', 'Diseases of sebaceous glands'), 3),
#  (('724', 'Other and unspecified disorders of back'), 3),
#  (('751', 'Genitourinary congenital anomalies'), 3),
#  (('781', 'Symptoms involving nervous and musculoskeletal systems'), 3),
#  (('281', 'Other deficiency anemia'), 3),
#  (('371', 'Inflammation of the eye'), 3),
#  (('382', 'Otalgia'), 3),
#  (('529', 'Diseases and other conditions of the tongue'), 3),
#  (('635', 'Hemorrhage during pregnancy; childbirth and postpartum'), 3),
#  (('759', 'Other and unspecified congenital anomalies'), 3),
#  (('973',
#    'Poisoning by agents primarily affecting the gastrointestinal system'),
#   3),
#  (('974', 'Poisoning by water, mineral, and uric acid metabolism drugs'), 3),
#  (('213', 'Benign neoplasm of bone and articular cartilage'), 2),
#  (('240', 'Simple and unspecified goiter'), 2),
#  (('249', 'Secondary diabetes mellitus'), 2),
#  (('325', 'Phlebitis and thrombophlebitis of intracranial venous sinuses'), 2),
#  (('385', 'Other disorders of middle ear and mastoid'), 2),
#  (('416', 'Cardiomegaly'), 2),
#  (('540', 'Appendiceal conditions'), 2),
#  (('853', 'Complication of colostomy or enterostomy'), 2),
#  (('601', 'Inflammatory diseases of prostate'), 2),
#  (('605', 'Erectile dysfunction [ED]'), 2),
#  (('625', 'Pain and other symptoms associated with female genital organs'), 2),
#  (('674', 'Other complications of the puerperium NEC'), 2),
#  (('689', 'Disorder of skin and subcutaneous tissue NOS'), 2),
#  (('765', 'Cervical radiculitis'), 2),
#  (('764', 'Sciatica'), 2),
#  (('269', 'Proteinuria'), 2),
#  (('611', 'Abnormal findings on mammogram or breast exam'), 2),
#  (('989',
#    'Toxic effect of other substances, chiefly nonmedicinal as to source'),
#   2),
#  (('857',
#    'Mechanical complication of unspecified genitourinary device, implant, and graft'),
#   2),
#  (('187', 'Cancer of other male genital organs'), 2),
#  (('977', 'Personal history of allergy to medicinal agents'), 2),
#  (('078', 'Viral warts & HPV'), 2),
#  (('158', 'Neoplasm of unspecified nature of digestive system'), 2),
#  (('256', 'Ovarian dysfunction'), 2),
#  (('259', 'Other endocrine disorders'), 2),
#  (('302', 'Sexual and gender identity disorders'), 2),
#  (('353', 'Nerve root and plexus disorders'), 2),
#  (('592', 'Cystitis and urethritis'), 2),
#  (('624', 'Symptoms involving female genital tract'), 2),
#  (('669', 'Complications of labor and delivery NEC'), 2),
#  (('702', 'Degenerative skin conditions and other dermatoses'), 2),
#  (('704', 'Diseases of hair and hair follicles'), 2),
#  (('723', 'Other disorders of cervical region'), 2),
#  (('731',
#    'Osteitis deformans and osteopathies associated with other disorders classified elsewhere'),
#   2),
#  (('976',
#    'Poisoning by agents primarily affecting skin & mucous membrane, ophthalmological, otorhinolaryngological, & dental drugs'),
#   2),
#  (('851', 'Complications of transplants and reattached limbs'), 2),
#  (('031', 'Diseases due to other mycobacteria'), 1),
#  (('133', 'Arthropod-borne diseases'), 1),
#  (('134', 'Helminthiases'), 1),
#  (('230', "Kaposi's sarcoma"), 1),
#  (('194', 'Cancer of other endocrine glands'), 1),
#  (('220', 'Benign neoplasm of ovary'), 1),
#  (('221', 'Benign neoplasm of other female genital organs'), 1),
#  (('223', 'Benign neoplasm of kidney and other urinary organs'), 1),
#  (('257', 'Testicular dysfunction'), 1),
#  (('312', 'Conduct disorders'), 1),
#  (('339', 'Other headache syndromes'), 1),
#  (('364', 'Corneal opacity and other disorders of cornea'), 1),
#  (('376', 'Disorders of the orbit'), 1),
#  (('448', 'Disease of capillaries'), 1),
#  (('472', 'Chronic pharyngitis and nasopharyngitis'), 1),
#  (('497', 'Bronchitis'), 1),
#  (('498', 'Acute bronchospasm'), 1),
#  (('527', 'Diseases of the salivary glands'), 1),
#  (('602', 'Other disorders of prostate'), 1),
#  (('603', 'Other disorders of testis'), 1),
#  (('604', 'Disorders of penis'), 1),
#  (('613', 'Other nonmalignant breast conditions'), 1),
#  (('636', 'Early or threatened labor; hemorrhage in early pregnancy'), 1),
#  (('646', 'Other complications of pregnancy NEC'), 1),
#  (('655',
#    'Known or suspected fetal abnormality affecting management of mother'),
#   1),
#  (('690', 'Erythematosquamous dermatosis'), 1),
#  (('931', 'Contact dermatitis and other eczema due to plants [except food]'),
#   1),
#  (('705', 'Disorders of sweat glands'), 1),
#  (('694', 'Dyschromia and Vitiligo'), 1),
#  (('713', 'Arthropathy associated with other disorders classified elsewhere'),
#   1),
#  (('739', 'Contracture of joint'), 1),
#  (('742', 'Derangement of joint, non-traumatic'), 1),
#  (('715', 'Other inflammatory spondylopathies'), 1),
#  (('763', 'Thoracic or lumbosacral neuritis or radiculitis, unspecified'), 1),
#  (('766', 'Neuralgia, neuritis, and radiculitis NOS'), 1),
#  (('732', 'Osteochondropathies'), 1),
#  (('736', 'Other acquired deformities of limbs'), 1),
#  (('756', 'Other congenital musculoskeletal anomalies'), 1),
#  (('478', 'Throat pain'), 1),
#  (('346', 'Abnormal findings on study of brain and/or nervous system'), 1),
#  (('589', 'Abnormal results of function study of kidney'), 1),
#  (('246', 'Other disorders of thyroid'), 1),
#  (('841', 'Sprains and strains of back and neck'), 1),
#  (('874', 'Complication of amputation stump'), 1),
#  (('980', 'Encounter for long-term (current) use of antibiotics'), 1)]

# %%
phecode_feat_idx_mapping = [(phecode, idx) for idx, phecode in enumerate(icd_phecode_name_mapping['phecode'].unique())]
phecode_feat_idx_mapping = dict(phecode_feat_idx_mapping)
pickle.dump(phecode_feat_idx_mapping, open("./data/phecode_feat_idx_mapping.p", 'wb'))

# %%
phecode_feat_idx_mapping = pickle.load(open("./data/phecode_feat_idx_mapping.p", 'rb'))
phecode_feat_idx_mapping
# Out:
# {'008': 0,
#  '038': 1,
#  '010': 2,
#  '041': 3,
#  '031': 4,
#  '480': 5,
#  '686': 6,
#  '465': 7,
#  '320': 8,
#  '420': 9,
#  '071': 10,
#  '324': 11,
#  '323': 12,
#  '079': 13,
#  '053': 14,
#  '369': 15,
#  '054': 16,
#  '070': 17,
#  '078': 18,
#  '136': 19,
#  '133': 20,
#  '130': 21,
#  '090': 22,
#  '711': 23,
#  '110': 24,
#  '112': 25,
#  '117': 26,
#  '134': 27,
#  '131': 28,
#  '132': 29,
#  '697': 30,
#  '145': 31,
#  '149': 32,
#  '150': 33,
#  '151': 34,
#  '159': 35,
#  '153': 36,
#  '155': 37,
#  '157': 38,
#  '165': 39,
#  '164': 40,
#  '170': 41,
#  '172': 42,
#  '174': 43,
#  '230': 44,
#  '182': 45,
#  '180': 46,
#  '184': 47,
#  '185': 48,
#  '187': 49,
#  '189': 50,
#  '190': 51,
#  '191': 52,
#  '193': 53,
#  '194': 54,
#  '195': 55,
#  '198': 56,
#  '202': 57,
#  '201': 58,
#  '204': 59,
#  '209': 60,
#  '208': 61,
#  '210': 62,
#  '211': 63,
#  '212': 64,
#  '213': 65,
#  '214': 66,
#  '215': 67,
#  '216': 68,
#  '610': 69,
#  '218': 70,
#  '220': 71,
#  '221': 72,
#  '223': 73,
#  '225': 74,
#  '226': 75,
#  '227': 76,
#  '228': 77,
#  '229': 78,
#  '158': 79,
#  '199': 80,
#  '173': 81,
#  '200': 82,
#  '851': 83,
#  '240': 84,
#  '241': 85,
#  '242': 86,
#  '244': 87,
#  '245': 88,
#  '246': 89,
#  '249': 90,
#  '250': 91,
#  '251': 92,
#  '258': 93,
#  '252': 94,
#  '253': 95,
#  '254': 96,
#  '255': 97,
#  '256': 98,
#  '627': 99,
#  '257': 100,
#  '259': 101,
#  '260': 102,
#  '261': 103,
#  '262': 104,
#  '263': 105,
#  '270': 106,
#  '271': 107,
#  '272': 108,
#  '277': 109,
#  '274': 110,
#  '275': 111,
#  '276': 112,
#  '942': 113,
#  '499': 114,
#  '278': 115,
#  '513': 116,
#  '279': 117,
#  '081': 118,
#  '280': 119,
#  '281': 120,
#  '282': 121,
#  '283': 122,
#  '285': 123,
#  '284': 124,
#  '286': 125,
#  '287': 126,
#  '288': 127,
#  '289': 128,
#  '964': 129,
#  '290': 130,
#  '317': 131,
#  '316': 132,
#  '295': 133,
#  '296': 134,
#  '300': 135,
#  '291': 136,
#  '313': 137,
#  '303': 138,
#  '301': 139,
#  '302': 140,
#  '318': 141,
#  '305.21': 142,
#  '305.2': 143,
#  '327': 144,
#  '306': 145,
#  '315': 146,
#  '304': 147,
#  '312': 148,
#  '325': 149,
#  '331': 150,
#  '292': 151,
#  '332': 152,
#  '349': 153,
#  '333': 154,
#  '334': 155,
#  '337': 156,
#  '355': 157,
#  '338': 158,
#  '340': 159,
#  '339': 160,
#  '335': 161,
#  '341': 162,
#  '342': 163,
#  '343': 164,
#  '344': 165,
#  '345': 166,
#  '347': 167,
#  '348': 168,
#  '967': 169,
#  '352': 170,
#  '353': 171,
#  '351': 172,
#  '356': 173,
#  '357': 174,
#  '358': 175,
#  '359': 176,
#  '371': 177,
#  '360': 178,
#  '361': 179,
#  '362': 180,
#  '363': 181,
#  '379': 182,
#  '365': 183,
#  '366': 184,
#  '367': 185,
#  '368': 186,
#  '370': 187,
#  '364': 188,
#  '372': 189,
#  '374': 190,
#  '375': 191,
#  '376': 192,
#  '377': 193,
#  '378': 194,
#  '380': 195,
#  '385': 196,
#  '381': 197,
#  '384': 198,
#  '386': 199,
#  '383': 200,
#  '389': 201,
#  '382': 202,
#  '388': 203,
#  '394': 204,
#  '428': 205,
#  '401': 206,
#  '411': 207,
#  '415': 208,
#  '452': 209,
#  '395': 210,
#  '425': 211,
#  '426': 212,
#  '427': 213,
#  '414': 214,
#  '416': 215,
#  '429': 216,
#  '430': 217,
#  '433': 218,
#  '440': 219,
#  '442': 220,
#  '443': 221,
#  '446': 222,
#  '444': 223,
#  '447': 224,
#  '448': 225,
#  '217': 226,
#  '451': 227,
#  '454': 228,
#  '455': 229,
#  '530': 230,
#  '450': 231,
#  '458': 232,
#  '459': 233,
#  '456': 234,
#  '464': 235,
#  '474': 236,
#  '483': 237,
#  '470': 238,
#  '471': 239,
#  '472': 240,
#  '475': 241,
#  '476': 242,
#  '479': 243,
#  '473': 244,
#  '481': 245,
#  '497': 246,
#  '496': 247,
#  '495': 248,
#  '500': 249,
#  '501': 250,
#  '506': 251,
#  '507': 252,
#  '503': 253,
#  '502': 254,
#  '504': 255,
#  '709': 256,
#  '509': 257,
#  '510': 258,
#  '508': 259,
#  '505': 260,
#  '519': 261,
#  '080': 262,
#  '498': 263,
#  '520': 264,
#  '521': 265,
#  '523': 266,
#  '522': 267,
#  '526': 268,
#  '524': 269,
#  '525': 270,
#  '527': 271,
#  '528': 272,
#  '963': 273,
#  '529': 274,
#  '531': 275,
#  '535': 276,
#  '536': 277,
#  '789': 278,
#  '564': 279,
#  '537': 280,
#  '539': 281,
#  '540': 282,
#  '550': 283,
#  '555': 284,
#  '441': 285,
#  '990': 286,
#  '569': 287,
#  '930': 288,
#  '558': 289,
#  '560': 290,
#  '562': 291,
#  '565': 292,
#  '567': 293,
#  '712': 294,
#  '568': 295,
#  '578': 296,
#  '556': 297,
#  '853': 298,
#  '573': 299,
#  '571': 300,
#  '574': 301,
#  '575': 302,
#  '577': 303,
#  '557': 304,
#  '580': 305,
#  '585': 306,
#  '588': 307,
#  '586': 308,
#  '590': 309,
#  '595': 310,
#  '594': 311,
#  '592': 312,
#  '596': 313,
#  '597': 314,
#  '591': 315,
#  '599': 316,
#  '593': 317,
#  '600': 318,
#  '601': 319,
#  '602': 320,
#  '603': 321,
#  '604': 322,
#  '605': 323,
#  '608': 324,
#  '613': 325,
#  '612': 326,
#  '611': 327,
#  '614': 328,
#  '615': 329,
#  '618': 330,
#  '628': 331,
#  '624': 332,
#  '619': 333,
#  '622': 334,
#  '623': 335,
#  '621': 336,
#  '626': 337,
#  '620': 338,
#  '625': 339,
#  '634': 340,
#  '635': 341,
#  '642': 342,
#  '643': 343,
#  '636': 344,
#  '646': 345,
#  '647': 346,
#  '649': 347,
#  '644': 348,
#  '654': 349,
#  '655': 350,
#  '653': 351,
#  '669': 352,
#  '671': 353,
#  '674': 354,
#  '681': 355,
#  '690': 356,
#  '949': 357,
#  '939': 358,
#  '931': 359,
#  '938': 360,
#  '695': 361,
#  '696': 362,
#  '698': 363,
#  '700': 364,
#  '701': 365,
#  '702': 366,
#  '703': 367,
#  '704': 368,
#  '705': 369,
#  '706': 370,
#  '707': 371,
#  '947': 372,
#  '694': 373,
#  '689': 374,
#  '713': 375,
#  '714': 376,
#  '740': 377,
#  '836': 378,
#  '716': 379,
#  '835': 380,
#  '742': 381,
#  '739': 382,
#  '741': 383,
#  '745': 384,
#  '715': 385,
#  '721': 386,
#  '722': 387,
#  '720': 388,
#  '761': 389,
#  '765': 390,
#  '723': 391,
#  '760': 392,
#  '764': 393,
#  '763': 394,
#  '724': 395,
#  '717': 396,
#  '726': 397,
#  '727': 398,
#  '735': 399,
#  '728': 400,
#  '772': 401,
#  '770': 402,
#  '766': 403,
#  '729': 404,
#  '771': 405,
#  '710': 406,
#  '731': 407,
#  '732': 408,
#  '743': 409,
#  '733': 410,
#  '736': 411,
#  '737': 412,
#  '738': 413,
#  '752': 414,
#  '753': 415,
#  '749': 416,
#  '747': 417,
#  '748': 418,
#  '750': 419,
#  '751': 420,
#  '755': 421,
#  '756': 422,
#  '754': 423,
#  '757': 424,
#  '691': 425,
#  '758': 426,
#  '759': 427,
#  '656': 428,
#  '657': 429,
#  '788': 430,
#  '783': 431,
#  '780': 432,
#  '798': 433,
#  '350': 434,
#  '781': 435,
#  '687': 436,
#  '782': 437,
#  '264': 438,
#  '478': 439,
#  '293': 440,
#  '477': 441,
#  '396': 442,
#  '791': 443,
#  '797': 444,
#  '994': 445,
#  '512': 446,
#  '516': 447,
#  '418': 448,
#  '532': 449,
#  '561': 450,
#  '785': 451,
#  '579': 452,
#  '572': 453,
#  '790': 454,
#  '796': 455,
#  '269': 456,
#  '598': 457,
#  '346': 458,
#  '514': 459,
#  '589': 460,
#  '794': 461,
#  '792': 462,
#  '795': 463,
#  '819': 464,
#  '805': 465,
#  '807': 466,
#  '809': 467,
#  '802': 468,
#  '803': 469,
#  '804': 470,
#  '800': 471,
#  '823': 472,
#  '801': 473,
#  '830': 474,
#  '840': 475,
#  '841': 476,
#  '842': 477,
#  '817': 478,
#  '816': 479,
#  '818': 480,
#  '870': 481,
#  '871': 482,
#  '872': 483,
#  '916': 484,
#  '907': 485,
#  '979': 486,
#  '911': 487,
#  '912': 488,
#  '910': 489,
#  '952': 490,
#  '957': 491,
#  '958': 492,
#  '850': 493,
#  '876': 494,
#  '960': 495,
#  '961': 496,
#  '962': 497,
#  '965': 498,
#  '966': 499,
#  '969': 500,
#  '971': 501,
#  '972': 502,
#  '973': 503,
#  '974': 504,
#  '975': 505,
#  '976': 506,
#  '981': 507,
#  '983': 508,
#  '985': 509,
#  '986': 510,
#  '987': 511,
#  '988': 512,
#  '989': 513,
#  '913': 514,
#  '946': 515,
#  '854': 516,
#  '855': 517,
#  '858': 518,
#  '859': 519,
#  '857': 520,
#  '587': 521,
#  '860': 522,
#  '856': 523,
#  '874': 524,
#  '875': 525,
#  '941': 526,
#  '297': 527,
#  '977': 528,
#  '559': 529,
#  '175': 530,
#  '196': 531,
#  '197': 532,
#  '980': 533,
#  '457': 534}

# %%
def phecode_feature_vector(ci):
    phecode_phenotype_freq_pairs_in_cluster_i = phecode_distribution_for_cluster_i(ci)
    phecode_phenotype_freq_tuples_in_cluster_i = sorted(phecode_phenotype_freq_pairs_in_cluster_i.items(), key=lambda p: p[1], reverse=True)
    feat_vec = np.zeros(len(phecode_feat_idx_mapping))
    for phecode_phenotype, freq in phecode_phenotype_freq_tuples_in_cluster_i:
        phecode = phecode_phenotype[0]
        phecode_feat_idx = phecode_feat_idx_mapping[phecode]
        feat_vec[phecode_feat_idx] = freq
    return feat_vec

phecode_featvecs = {}
def weighted_jaccard_similarity(ci1, ci2):
    
    if ci1 in phecode_featvecs:
        phecode_f1 = phecode_featvecs[ci1]
    else:
        phecode_f1 = phecode_feature_vector(ci1)
        phecode_featvecs[ci1] = phecode_f1

    if ci2 in phecode_featvecs:
        phecode_f2 = phecode_featvecs[ci2]
    else:
        phecode_f2 = phecode_feature_vector(ci2)
        phecode_featvecs[ci2] = phecode_f2
        
    
    f1_f2_matrix = np.vstack([phecode_f1, phecode_f2])
    jaccard_num = np.sum(np.amin(f1_f2_matrix, axis=0))
    jaccard_den = np.sum(np.amax(f1_f2_matrix, axis=0))

    j_weighted_score = jaccard_num / jaccard_den
    
    return j_weighted_score

# %%
colnames = ['c{}'.format(i) for i in range(50)]

jaccard_adj_matrix = np.zeros((50,50))
for ci1 in range(50):
    for ci2 in range(50):
        jaccard_adj_matrix[ci1, ci2] = weighted_jaccard_similarity(ci1, ci2)

jaccard_adj_matrix_df = pd.DataFrame(data=jaccard_adj_matrix, columns=colnames)
jaccard_adj_matrix_df.to_csv("./data/adj_matrix_jaccardsim_NOT_mc.csv", index=False)

# %%
jaccard_adj_matrix_df = pd.read_csv("./data/adj_matrix_jaccardsim_NOT_mc.csv")
jaccard_adj_matrix_df
# Out:
#           c0        c1        c2        c3        c4        c5        c6  \
# 0   1.000000  0.333789  0.458319  0.437018  0.413112  0.058787  0.591611
# 1   0.333789  1.000000  0.491252  0.190299  0.374347  0.063581  0.375058
# 2   0.458319  0.491252  1.000000  0.364798  0.527423  0.075076  0.423554
# 3   0.437018  0.190299  0.364798  1.000000  0.352932  0.079830  0.282972
# 4   0.413112  0.374347  0.527423  0.352932  1.000000  0.101695  0.329512
# 5   0.058787  0.063581  0.075076  0.079830  0.101695  1.000000  0.046676
# 6   0.591611  0.375058  0.423554  0.282972  0.329512  0.046676  1.000000
# 7   0.164907  0.127670  0.202258  0.254731  0.304535  0.162691  0.118239
# 8   0.162993  0.137452  0.195339  0.251353  0.267249  0.179496  0.117187
# 9   0.438193  0.208885  0.394664  0.652359  0.336580  0.064388  0.281685
# 10  0.327178  0.385563  0.352804  0.174726  0.332577  0.064049  0.377906
# 11  0.078178  0.072936  0.095339  0.118651  0.152656  0.174980  0.057142
# 12  0.039860  0.041636  0.050551  0.062855  0.072608  0.400491  0.030093
# 13  0.041760  0.043307  0.053124  0.066229  0.078118  0.283180  0.031173
# 14  0.336178  0.628988  0.450423  0.187351  0.377287  0.066892  0.376689
# 15  0.417828  0.373046  0.400726  0.227244  0.335856  0.050739  0.520797
# 16  0.162051  0.263936  0.209424  0.130415  0.221457  0.072177  0.144162
# 17  0.311886  0.507746  0.516709  0.231561  0.507212  0.091338  0.298720
# 18  0.618837  0.383300  0.501954  0.346373  0.433333  0.067874  0.539458
# 19  0.062719  0.061984  0.077869  0.095404  0.115654  0.279847  0.046134
# 20  0.283244  0.215481  0.336581  0.431533  0.443229  0.117188  0.205852
# 21  0.133762  0.119986  0.162017  0.187569  0.257167  0.184324  0.096667
# 22  0.290395  0.280140  0.359239  0.340718  0.482553  0.129241  0.220738
# 23  0.556612  0.231157  0.362647  0.618994  0.373671  0.078672  0.330193
# 24  0.037380  0.040826  0.047495  0.058417  0.067376  0.453136  0.028728
# 25  0.168012  0.128735  0.192498  0.247694  0.276441  0.204568  0.121808
# 26  0.418300  0.275456  0.322407  0.245416  0.211238  0.031259  0.497463
# 27  0.156470  0.145061  0.196004  0.223423  0.290020  0.160099  0.114593
# 28  0.397309  0.307271  0.476619  0.445088  0.545676  0.106671  0.298592
# 29  0.455218  0.549277  0.587118  0.293154  0.474140  0.068748  0.494167
# 30  0.286729  0.343690  0.409888  0.319183  0.470417  0.100093  0.243725
# 31  0.491401  0.463573  0.666056  0.427845  0.469194  0.075208  0.443765
# 32  0.529761  0.218099  0.381173  0.691692  0.356232  0.068237  0.339543
# 33  0.092734  0.089730  0.114753  0.141655  0.176540  0.219051  0.067061
# 34  0.243027  0.267402  0.306396  0.251371  0.429037  0.121111  0.199991
# 35  0.692688  0.313534  0.441253  0.428082  0.338344  0.049962  0.557346
# 36  0.452210  0.199909  0.317299  0.570879  0.371209  0.092286  0.275491
# 37  0.109499  0.102361  0.134687  0.162060  0.209069  0.184055  0.080211
# 38  0.335399  0.456080  0.452625  0.219116  0.504363  0.096686  0.329727
# 39  0.485997  0.330311  0.377411  0.260653  0.283695  0.041231  0.625376
# 40  0.090114  0.086371  0.111916  0.139272  0.169617  0.233458  0.065883
# 41  0.107834  0.106746  0.134672  0.159890  0.198754  0.326930  0.079436
# 42  0.033431  0.033458  0.040938  0.051101  0.063364  0.222323  0.024677
# 43  0.112449  0.117235  0.142976  0.162041  0.218657  0.164010  0.083684
# 44  0.350229  0.397075  0.350400  0.172538  0.243011  0.036248  0.522072
# 45  0.477114  0.370778  0.574845  0.456141  0.478711  0.075519  0.402903
# 46  0.447063  0.415883  0.517113  0.295392  0.529921  0.086026  0.420233
# 47  0.244426  0.119267  0.201620  0.399939  0.289452  0.126910  0.157351
# 48  0.470463  0.454435  0.572812  0.340207  0.492850  0.078239  0.413576
# 49  0.112406  0.108354  0.142287  0.170737  0.213616  0.199247  0.082523
#
#           c7        c8        c9  ...       c40       c41       c42       c43  \
# 0   0.164907  0.162993  0.438193  ...  0.090114  0.107834  0.033431  0.112449
# 1   0.127670  0.137452  0.208885  ...  0.086371  0.106746  0.033458  0.117235
# 2   0.202258  0.195339  0.394664  ...  0.111916  0.134672  0.040938  0.142976
# 3   0.254731  0.251353  0.652359  ...  0.139272  0.159890  0.051101  0.162041
# 4   0.304535  0.267249  0.336580  ...  0.169617  0.198754  0.063364  0.218657
# 5   0.162691  0.179496  0.064388  ...  0.233458  0.326930  0.222323  0.164010
# 6   0.118239  0.117187  0.281685  ...  0.065883  0.079436  0.024677  0.083684
# 7   1.000000  0.590922  0.212809  ...  0.403766  0.402407  0.177668  0.441344
# 8   0.590922  1.000000  0.208942  ...  0.453965  0.435195  0.209288  0.397714
# 9   0.212809  0.208942  1.000000  ...  0.114883  0.129444  0.042907  0.137347
# 10  0.135319  0.136492  0.181671  ...  0.090742  0.108279  0.035159  0.106817
# 11  0.383399  0.407748  0.098440  ...  0.500889  0.421534  0.320296  0.430213
# 12  0.174919  0.204306  0.052352  ...  0.342631  0.362605  0.423186  0.194395
# 13  0.205091  0.240233  0.055198  ...  0.419533  0.434300  0.578475  0.240561
# 14  0.143306  0.152582  0.199945  ...  0.097962  0.119284  0.037749  0.131832
# 15  0.128326  0.126017  0.222481  ...  0.073319  0.089232  0.027097  0.091502
# 16  0.141056  0.140875  0.128817  ...  0.099231  0.123027  0.045507  0.139161
# 17  0.184859  0.197535  0.244963  ...  0.126584  0.156341  0.051581  0.174440
# 18  0.188873  0.187857  0.312561  ...  0.103647  0.123741  0.038510  0.130816
# 19  0.283702  0.320383  0.078609  ...  0.515391  0.505594  0.533001  0.302988
# 20  0.436402  0.380555  0.363152  ...  0.241013  0.263158  0.093027  0.325280
# 21  0.535289  0.512274  0.151321  ...  0.493779  0.475136  0.223941  0.454269
# 22  0.384689  0.351095  0.304281  ...  0.245357  0.276570  0.096322  0.323432
# 23  0.245283  0.244890  0.515996  ...  0.132643  0.151267  0.049202  0.151594
# 24  0.156941  0.179868  0.047296  ...  0.300922  0.354885  0.387570  0.172154
# 25  0.544324  0.493696  0.206340  ...  0.480508  0.459126  0.247059  0.388663
# 26  0.071791  0.071593  0.268500  ...  0.040311  0.049380  0.014897  0.051157
# 27  0.523158  0.487131  0.186934  ...  0.395545  0.407437  0.162079  0.497632
# 28  0.346249  0.332035  0.388889  ...  0.191484  0.224120  0.072691  0.262043
# 29  0.167230  0.166363  0.300693  ...  0.102395  0.125884  0.038359  0.139416
# 30  0.268574  0.250363  0.289396  ...  0.177456  0.207640  0.066808  0.238337
# 31  0.181090  0.176478  0.441052  ...  0.104225  0.128143  0.040629  0.133382
# 32  0.208724  0.209299  0.650248  ...  0.112243  0.128496  0.042473  0.131083
# 33  0.439312  0.472506  0.114739  ...  0.551869  0.506916  0.341591  0.457263
# 34  0.320155  0.303026  0.226346  ...  0.231464  0.263946  0.088725  0.258005
# 35  0.127444  0.125781  0.468209  ...  0.070704  0.085490  0.026581  0.087498
# 36  0.317436  0.315062  0.485487  ...  0.172683  0.186906  0.066683  0.191277
# 37  0.466606  0.486015  0.134740  ...  0.519035  0.481376  0.270052  0.453619
# 38  0.218760  0.221448  0.213130  ...  0.150016  0.180912  0.060183  0.192262
# 39  0.100994  0.100200  0.253209  ...  0.056407  0.068323  0.020937  0.070164
# 40  0.403766  0.453965  0.114883  ...  1.000000  0.540577  0.400187  0.401761
# 41  0.402407  0.435195  0.129444  ...  0.540577  1.000000  0.374671  0.405144
# 42  0.177668  0.209288  0.042907  ...  0.400187  0.374671  1.000000  0.212192
# 43  0.441344  0.397714  0.137347  ...  0.401761  0.405144  0.212192  1.000000
# 44  0.080332  0.078267  0.184355  ...  0.046364  0.056852  0.017812  0.059886
# 45  0.206512  0.204469  0.400251  ...  0.114077  0.135555  0.042614  0.148734
# 46  0.233007  0.218324  0.283616  ...  0.140885  0.166136  0.053183  0.176911
# 47  0.453910  0.420773  0.332435  ...  0.281953  0.274439  0.125191  0.275690
# 48  0.214246  0.211493  0.305021  ...  0.118988  0.141867  0.043677  0.151344
# 49  0.501558  0.484574  0.136510  ...  0.508302  0.482660  0.240255  0.481588
#
#          c44       c45       c46       c47       c48       c49
# 0   0.350229  0.477114  0.447063  0.244426  0.470463  0.112406
# 1   0.397075  0.370778  0.415883  0.119267  0.454435  0.108354
# 2   0.350400  0.574845  0.517113  0.201620  0.572812  0.142287
# 3   0.172538  0.456141  0.295392  0.399939  0.340207  0.170737
# 4   0.243011  0.478711  0.529921  0.289452  0.492850  0.213616
# 5   0.036248  0.075519  0.086026  0.126910  0.078239  0.199247
# 6   0.522072  0.402903  0.420233  0.157351  0.413576  0.082523
# 7   0.080332  0.206512  0.233007  0.453910  0.214246  0.501558
# 8   0.078267  0.204469  0.218324  0.420773  0.211493  0.484574
# 9   0.184355  0.400251  0.283616  0.332435  0.305021  0.136510
# 10  0.336108  0.293645  0.447236  0.124283  0.367909  0.108049
# 11  0.039793  0.097456  0.124300  0.242098  0.101600  0.474926
# 12  0.022072  0.051581  0.061203  0.134756  0.053802  0.231853
# 13  0.022619  0.054951  0.065493  0.149447  0.056091  0.275202
# 14  0.366158  0.344947  0.473233  0.131304  0.443646  0.124160
# 15  0.530486  0.361082  0.485873  0.136374  0.415678  0.091210
# 16  0.127403  0.191322  0.228403  0.109630  0.221609  0.126931
# 17  0.290947  0.373816  0.387814  0.163857  0.434320  0.160882
# 18  0.346801  0.574282  0.518242  0.203496  0.632556  0.130506
# 19  0.033010  0.078926  0.095926  0.196333  0.082029  0.379487
# 20  0.144155  0.376697  0.356895  0.457427  0.327495  0.306765
# 21  0.066602  0.165073  0.209638  0.339928  0.172706  0.609602
# 22  0.163537  0.402012  0.421196  0.387443  0.355693  0.313286
# 23  0.198677  0.473205  0.336155  0.358058  0.437627  0.162625
# 24  0.021264  0.048451  0.056738  0.117300  0.050458  0.210043
# 25  0.082813  0.200045  0.233841  0.418099  0.204719  0.468687
# 26  0.496491  0.333191  0.260873  0.107318  0.316193  0.051022
# 27  0.079664  0.200680  0.233305  0.333595  0.204341  0.516088
# 28  0.204847  0.506773  0.498439  0.359367  0.447112  0.250925
# 29  0.399581  0.469903  0.615514  0.170885  0.512063  0.128798
# 30  0.183431  0.390055  0.417755  0.249569  0.365666  0.220900
# 31  0.351731  0.605625  0.461650  0.214553  0.527466  0.132567
# 32  0.209287  0.492677  0.303728  0.326958  0.383841  0.136611
# 33  0.047024  0.117089  0.144168  0.278978  0.121741  0.531488
# 34  0.153511  0.278891  0.384500  0.280183  0.301958  0.272928
# 35  0.370990  0.496482  0.360135  0.190292  0.445045  0.086810
# 36  0.166537  0.367300  0.318016  0.461074  0.355227  0.204983
# 37  0.056829  0.136032  0.172831  0.300168  0.142136  0.543866
# 38  0.266790  0.369157  0.527789  0.174833  0.490479  0.185221
# 39  0.599136  0.395053  0.372342  0.143600  0.405492  0.070405
# 40  0.046364  0.114077  0.140885  0.281953  0.118988  0.508302
# 41  0.056852  0.135555  0.166136  0.274439  0.141867  0.482660
# 42  0.017812  0.042614  0.053183  0.125191  0.043677  0.240255
# 43  0.059886  0.148734  0.176911  0.275690  0.151344  0.481588
# 44  1.000000  0.294237  0.308491  0.089542  0.317984  0.059152
# 45  0.294237  1.000000  0.443178  0.228159  0.661224  0.146694
# 46  0.308491  0.443178  1.000000  0.235624  0.513356  0.174050
# 47  0.089542  0.228159  0.235624  1.000000  0.199709  0.319272
# 48  0.317984  0.661224  0.513356  0.199709  1.000000  0.152344
# 49  0.059152  0.146694  0.174050  0.319272  0.152344  1.000000
#
# [50 rows x 50 columns]

# %%
top_phecodes = []
for ci in tqdm(range(50)):
    phecode_phenotype_freq_pairs_in_cluster_i = phecode_distribution_for_cluster_i(ci)
    most_common_phecode = max(phecode_phenotype_freq_pairs_in_cluster_i.items(), key=lambda p: p[1])
    top_phecodes.append(most_common_phecode)
    
#Looking for number of most common codes
most_common_phecodes = [p[0] for p in top_phecodes]
print(len(Counter(most_common_phecodes).keys()))
print(Counter(most_common_phecodes).values())

# %%
cluster_sizes = sorted(Counter(Y_cluster_labels).items(), key=lambda x: x[0])
cluster_sizes = [p[1] for p in cluster_sizes]
cluster_sizes
# Out:
# [914,
#  1909,
#  1419,
#  1192,
#  636,
#  673,
#  894,
#  360,
#  353,
#  1453,
#  779,
#  264,
#  755,
#  375,
#  1221,
#  1158,
#  1756,
#  1491,
#  966,
#  516,
#  711,
#  296,
#  663,
#  971,
#  638,
#  478,
#  1789,
#  298,
#  741,
#  978,
#  893,
#  1322,
#  1217,
#  358,
#  342,
#  1133,
#  768,
#  311,
#  870,
#  1362,
#  456,
#  317,
#  413,
#  318,
#  2132,
#  1119,
#  541,
#  592,
#  1120,
#  286]

# %%
phecode_color_idx = enumerate(Counter(most_common_phecodes).keys())
phecode_color_idx = dict([(v, k) for k, v in phecode_color_idx])
print(phecode_color_idx)
nodes_colors = [phecode_color_idx[tup] for tup in most_common_phecodes]
nodes_colors
# Out:
# {('411', 'Ischemic Heart Disease'): 0, ('276', 'Disorders of fluid, electrolyte, and acid-base balance'): 1, ('401', 'Hypertension'): 2, ('656', 'Other perinatal conditions of fetus or newborn'): 3, ('250', 'Diabetes mellitus'): 4, ('427', 'Cardiac dysrhythmias'): 5, ('571', 'Chronic liver disease and cirrhosis'): 6, ('994', 'Sepsis and SIRS'): 7, ('819', 'Skull and face fracture and other intercranial injury'): 8, ('198', 'Secondary malignant neoplasm'): 9, ('428', 'Congestive heart failure; nonhypertensive'): 10, ('272', 'Disorders of lipoid metabolism'): 11, ('430', 'Intracranial hemorrhage'): 12}
# [0,
#  1,
#  2,
#  0,
#  2,
#  3,
#  4,
#  0,
#  5,
#  0,
#  6,
#  3,
#  3,
#  3,
#  1,
#  7,
#  8,
#  9,
#  10,
#  3,
#  11,
#  0,
#  2,
#  0,
#  3,
#  4,
#  10,
#  2,
#  2,
#  2,
#  2,
#  11,
#  0,
#  3,
#  6,
#  0,
#  0,
#  3,
#  1,
#  10,
#  3,
#  3,
#  3,
#  12,
#  1,
#  5,
#  1,
#  0,
#  5,
#  0]

# %%
nodes_labels = []
for phecode, phenotype in most_common_phecodes:
    node_label = "({}, {})".format(phecode, phenotype)
    nodes_labels.append(node_label)
print(nodes_labels[0])

nodes_dict = {"Id": [i for i in range(50)], 
              "Label": nodes_labels,
              "Size": cluster_sizes, 
              "Color": nodes_colors}
nodes_df = pd.DataFrame(nodes_dict)
nodes_df.to_csv("./tests/nodes.csv", index=False)
nodes_df = pd.read_csv("./tests/nodes.csv")
nodes_df.head()
# Out:
# (411, Ischemic Heart Disease)
#    Id                                              Label  Size  Color
# 0   0                      (411, Ischemic Heart Disease)   914      0
# 1   1  (276, Disorders of fluid, electrolyte, and aci...  1909      1
# 2   2                                (401, Hypertension)  1419      2
# 3   3                      (411, Ischemic Heart Disease)  1192      0
# 4   4                                (401, Hypertension)   636      2

# %%
edges_sources = []
for i in range(50):
    edges_sources += [i] * 50

edges_targets = list(range(50)) * 50
edges_types = ["Undirected"] * 2500
edges_ids = list(range(2500))

edges_weights = []
for i in range(50):
    edges_weights += jaccard_adj_matrix_df.iloc[i].values.tolist()

print(len(edges_sources))
print(len(edges_targets))
print(len(edges_types))
print(len(edges_ids))
print(len(edges_weights))

edges_dict = {"Source": edges_sources, 
              "Target": edges_targets, 
              "Type": edges_types, 
              "Id": edges_ids, 
              "Weight": edges_weights}



edges_df = pd.DataFrame(edges_dict)
sim_thresh = 0
edges_df = edges_df[edges_df["Weight"] > sim_thresh]

edges_df.to_csv("./tests/edges.csv", index=False)
edges_df = pd.read_csv("./tests/edges.csv")
edges_df.head()
# Out:
# 2500
# 2500
# 2500
# 2500
# 2500
#    Source  Target        Type  Id    Weight
# 0       0       1  Undirected   1  0.333789
# 1       0       2  Undirected   2  0.458319
# 2       0       3  Undirected   3  0.437018
# 3       0       4  Undirected   4  0.413112
# 4       0       5  Undirected   5  0.058787

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

k_neighbors = 50
evecs=50

L_evals = pickle.load(open("./data/L_evals{}_K{}.p".format(evecs, k_neighbors), "rb"))
L_evecs = pickle.load(open("./data/L_evecs{}_K{}.p".format(evecs, k_neighbors), 'rb'))

L_mc_evals = pickle.load(open("./data/L_mc_evals{}_K{}.p".format(evecs, k_neighbors), "rb"))
L_mc_evecs = pickle.load(open("./data/L_mc_evecs{}_K{}.p".format(evecs, k_neighbors), "rb"))

def get_Y(evecs, drop_k_evecs = 1, keep_top_k_evecs = 5):
    X_top_k = evecs[:, -drop_k_evecs-keep_top_k_evecs:-drop_k_evecs]
    evecs_lengths_top_k = np.linalg.norm(X_top_k, axis=1)
    Y_top_k = X_top_k / evecs_lengths_top_k[:, None]
    return Y_top_k[~np.isnan(Y_top_k).any(axis=1)]
    #return Y_top_k

keep_k_evecs=10
drop_k_evecs=2
Y = get_Y(L_evecs, drop_k_evecs=drop_k_evecs, keep_top_k_evecs=keep_k_evecs)
Y_mc = get_Y(L_mc_evecs, drop_k_evecs=drop_k_evecs, keep_top_k_evecs=keep_k_evecs)

print(Y.shape, Y_mc.shape)
# Out:
# (42517, 10) (42517, 10)

# %%
sample_silhouette_values = silhouette_samples(Y, Y_cluster_labels)

# %%
sil_scores.shape
# Out:
# (42517,)

# %%
import matplotlib.cm as cm

cluster_labels = Y_cluster_labels
plt.figure(figsize=(10,10))
y_lower = 10
n_clusters = 50

fig, ax1 = plt.subplots(1, 1)

silhouette_avg = silhouette_score(Y, Y_cluster_labels)

for i in range(n_clusters):
    # Aggregate the silhouette scores for samples belonging to
    # cluster i, and sort them
    ith_cluster_silhouette_values = \
        sample_silhouette_values[cluster_labels == i]

    ith_cluster_silhouette_values.sort()

    size_cluster_i = ith_cluster_silhouette_values.shape[0]
    y_upper = y_lower + size_cluster_i

    color = cm.nipy_spectral(float(i) / n_clusters)
    ax1.fill_betweenx(np.arange(y_lower, y_upper),
                      0, ith_cluster_silhouette_values,
                      facecolor=color, edgecolor=color, alpha=0.7)

    # Label the silhouette plots with their cluster numbers at the middle
#     ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

    # Compute the new y_lower for next plot
    y_lower = y_upper + 10  # 10 for the 0 samples

ax1.set_title("The silhouette plot for the various clusters.")
ax1.set_xlabel("The silhouette coefficient values")
ax1.set_ylabel("Cluster label")

# The vertical line for average silhouette score of all the values
ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

# ax1.set_yticks([])  # Clear the yaxis labels / ticks
# ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
# Out:
# [<matplotlib.axis.XTick at 0x1a258f1940>,
#  <matplotlib.axis.XTick at 0x1a258f12e8>,
#  <matplotlib.axis.XTick at 0x1a258f1160>,
#  <matplotlib.axis.XTick at 0x1a212e9748>,
#  <matplotlib.axis.XTick at 0x1a212e9c18>,
#  <matplotlib.axis.XTick at 0x1a212f3198>,
#  <matplotlib.axis.XTick at 0x1a212f3710>]
