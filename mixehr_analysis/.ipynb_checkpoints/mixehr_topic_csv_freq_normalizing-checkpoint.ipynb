# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
from wordcloud import WordCloud

# %%
phi_with_pheNames = pd.read_csv("/Users/andrew/Documents/meng/mixEHR/data/precomputed_results/mixmimic/mimic_trainData_JCVB0_nmar_K75_iter5497_phi_normalized_WITH_PHENAMES.csv")

# %%
topic_cols = [str(i) for i in range(1, 76)]
topic_freqs = phi_with_pheNames[topic_cols]
topic_freqs_normalized = topic_freqs / np.min(topic_freqs, axis=0)
phi_with_pheNames[topic_cols] = topic_freqs_normalized
phi_with_pheNames.to_csv("/Users/andrew/Documents/meng/mixEHR/data/precomputed_results/mixmimic/mimic_trainData_JCVB0_nmar_K75_iter5497_phi_normalized_FREQS_WITH_PHENAMES.csv", index=False)

# %%
phi_with_freqs_pheNames = pd.read_csv('/Users/andrew/Documents/meng/mixEHR/data/precomputed_results/mixmimic/mimic_trainData_JCVB0_nmar_K75_iter5497_phi_normalized_FREQS_WITH_PHENAMES.csv')
phi_with_freqs_pheNames
# Out:
#        typeId  pheId                                            pheName  \
# 0           1      1                                                 aa
# 1           1      2                                                aaa
# 2           1      3                                          aaarepair
# 3           1      4                                             aaataa
# 4           1      5                                               aado
# ...       ...    ...                                                ...
# 52863       6   3082  MS_988_NON-EXTENSIVE O.R. PROC UNRELATED TO PR...
# 52864       6   3083  MS_989_NON-EXTENSIVE O.R. PROC UNRELATED TO PR...
# 52865       6   3084  MS_98_NON-BACTERIAL INFECT OF NERVOUS SYS EXC ...
# 52866       6   3085  MS_99_NON-BACTERIAL INFECT OF NERVOUS SYS EXC ...
# 52867       6   3086                                        MS_9__NA_NA
#
#                  1            2            3            4            5  \
# ...

# %%
for i in range(1, 76):
    key = str(i)
    print(topic_freqs[topic_freqs[key] == np.min(topic_freqs[key])].index.tolist())
# Out:
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [3938]
# [9796]
# [3938]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [3938]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [3938]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]
# [9796]

# %%
idx = 68
min_vals = np.min(topic_freqs, axis=0)[idx]
topic_freqs[topic_freqs[str(idx + 1)] == min_vals].index.tolist()
# Out:
# [3938]
